# %% [markdown]
# <!-- TOC -->
#
# - [9.Support Vector Machines](#9support-vector-machines)
#     - [9.1 Maximal Margin Classifier](#91-maximal-margin-classifier)
#         - [9.1.1 What Is a Hyperplane?](#911-what-is-a-hyperplane)
#         - [9.1.2 Classification Using a Separating Hyperplane](#912-classification-using-a-separating-hyperplane)
#         - [9.1.3 The Maximal Margin Classifier](#913-the-maximal-margin-classifier)
#         - [9.1.4 Construction of the Maximal Margin Classifier](#914-construction-of-the-maximal-margin-classifier)
#         - [9.1.5 The Non-separable Case](#915-the-non-separable-case)
#     - [9.2 Support Vector Classifiers](#92-support-vector-classifiers)
#         - [9.2.1 Overview of the Support Vector Classifier](#921-overview-of-the-support-vector-classifier)
#         - [9.2.2 Details of the Support Vector Classifier](#922-details-of-the-support-vector-classifier)
#     - [9.3 Support Vector Machines](#93-support-vector-machines)
#         - [9.3.1 Classification with Non-linear Decision Boundaries](#931-classification-with-non-linear-decision-boundaries)
#         - [9.3.2 The Support Vector Machine](#932-the-support-vector-machine)
#         - [9.3.3 An Application to the Heart Disease Data](#933-an-application-to-the-heart-disease-data)
#     - [9.4 SVMs with More than Two Classes](#94-svms-with-more-than-two-classes)
#         - [9.4.1 One-Versus-One Classification](#941-one-versus-one-classification)
#         - [9.4.2 One-Versus-All Classification](#942-one-versus-all-classification)
#     - [9.5 Relationship to Logistic Regression](#95-relationship-to-logistic-regression)
#     - [9.6 Lab: Support Vector Machines](#96-lab-support-vector-machines)
#         - [9.6.1 Support Vector Classifier](#961-support-vector-classifier)
#         - [9.6.2 Support Vector Machine](#962-support-vector-machine)
#         - [9.6.3 ROC Curves](#963-roc-curves)
#         - [9.6.4 SVM with Multiple Classes](#964-svm-with-multiple-classes)
#         - [9.6.5 Application to Gene Expression Data](#965-application-to-gene-expression-data)
#
# <!-- /TOC -->
#
# # 9.Support Vector Machines
# ## 9.1 Maximal Margin Classifier
# ### 9.1.1 What Is a Hyperplane?
# In a p-dimensional space, a **hyperplane** is a flat affine subspace of dimension p − 1.
#
# In two dimensions, a hyperplane is defined by the equation
#
# $\beta_0+\beta_1X_1+\beta_2X_2=0\ (9.1)$
#
# Note that (9.1) is simply the equation of a line, since indeed in two dimensions a hyperplane is a line. Equation 9.1 can be easily extended to the p-dimensional setting:
#
# $\beta_0+\beta_1X_1+\beta_2X_2+\cdots+\beta_pX_p=0\ (9.2)$
#
# defines a p-dimensional hyperplane, again in the sense that if a point $X = (X_1,X_2,\cdots,X_p)^T$ in p-dimensional space(i.e. a vector of length p)satisfies (9.2), then X lies on the hyperplane.
#
# ![](http://ou8qjsj0m.bkt.clouddn.com//17-12-28/55725800.jpg)
#
# ### 9.1.2 Classification Using a Separating Hyperplane
# Now suppose that we have a n×p data matrix X that consists of n training observations in p-dimensional space,
#
# $$
# x_1=\left(
# \begin{matrix}
# x_{11} \\
# \vdots \\
# x_{1p}
# \end{matrix}
# \right),\cdots,x_n=\left(
# \begin{matrix}
# x_{n1} \\
# \vdots \\
# x_{np}
# \end{matrix}
# \right),\ (9.5)
# $$
#
# and that these observations fall into two classes—that is, y1, . . . , yn ∈ {-1,1} where -1 represents one class and 1 the other class. We also have a test observation, a p-vector of observed features $x^* =  (x_1^*,\cdots, x_p^*)^T$ . Our goal is to develop a classifier based on the training data that will correctly classify the test observation using its feature measurements.
#
# We will now see a new approach that is based upon the concept of a **separating hyperplane**.
#
# A separating hyperplane has the property that
#
# $\beta_0+\beta_1x_{i1}+\beta_2x_{i2}+\cdots+\beta_px_{ip} > 0\ if\ y_i=1,\ (9.6)$
#
# and
#
# $\beta_0+\beta_1x_{i1}+\beta_2x_{i2}+\cdots+\beta_px_{ip} < 0\ if\ y_i=-1,\ (9.7)$
#
# Equivalently, a separating hyperplane has the property that
#
# $y_i\beta_0+\beta_1x_{i1}+\beta_2x_{i2}+\cdots+\beta_px_{ip} > 0,\ (9.8)$
#
# for all i = 1,...,n.
#
# ### 9.1.3 The Maximal Margin Classifier
# ![](http://ou8qjsj0m.bkt.clouddn.com//17-12-28/11353314.jpg)
#
# ### 9.1.4 Construction of the Maximal Margin Classifier
# The maximal margin hyperplane is the solution to the optimization problem
#
# $maximize_{\beta_0,\beta_1,\cdots,\beta_p}M\ (9.9)$
#
# $subject\ to\ \sum_{j=1}^p\beta_j^2=1,\ (9.10)$
#
# $y_i(\beta_0+\beta_1x_{i1}+\beta_2x_{i2}+\cdots+\beta_px_{ip}) \ge M\ \forall i=1,\cdots,n.\ (9.11)$
#
# (9.10) adds meaning to (9.11); one can show that with this constraint the perpendicular distance from the ith observation to the hyperplane is given by
#
# $y_i(\beta_0+\beta_1x_{i1}+\beta_2x_{i2}+\cdots+\beta_px_{ip}).$
#
# Therefore, the constraints (9.10) and (9.11) ensure that each observation is on the correct side of the hyperplane and at least a distance M from the hyperplane.
#
# ### 9.1.5 The Non-separable Case
# The generalization of the maximal margin classifier to the non-separable case is known as the **support vector classifier**.
#
# ## 9.2 Support Vector Classifiers
# ### 9.2.1 Overview of the Support Vector Classifier
# An example is shown in Figure 9.5. The addition of a single observation in the right-hand panel of Figure 9.5 leads to a dramatic change in the maxi- mal margin hyperplane. The resulting maximal margin hyperplane is not satisfactory—for one thing, it has only a tiny margin.
#
# ![](http://ou8qjsj0m.bkt.clouddn.com//17-12-28/19581945.jpg)
#
# In this case, we might be willing to consider a classifier based on a hyperplane that does not perfectly separate the two classes, in the interest of
#
# - Greater robustness to individual observations, and
# - Better classification of most of the training observations.
#
# The **support vector classifier**, sometimes called a **soft margin classifier**, does exactly this.
#
# ### 9.2.2 Details of the Support Vector Classifier
# It is the solution to the optimization problem
#
# $maximize_{\beta_0,\beta_1,\cdots,\beta_p,\epsilon_1,\cdots,\epsilon_n}M\ (9.12)$
#
# $subject\ to\ \sum_{j=1}^p\beta_j^2=1,\ (9.13)$
#
# $y_i(\beta_0+\beta_1x_{i1}+\beta_2x_{i2}+\cdots+\beta_px_{ip}) \ge M(1-\epsilon_i),\ (9.14)$
#
# $\epsilon_i \ge 0,\sum_{i=1}^n\epsilon_i \le C,\ (9.15)$
#
# where
#
# - C is a nonnegative tuning parameter.
# - In (9.11), M is the width of the margin; we seek to make this quantity as large as possible.
# - In (9.14), ε1,...,εn are **slack variables** that allow individual observations to be on the wrong side of the margin or the hyperplane.
#
# ## 9.3 Support Vector Machines
# ### 9.3.1 Classification with Non-linear Decision Boundaries
# Rather than fitting a support vector classifier using p features
#
# $X_1,X_2,\cdots,X_p,$
#
# we could instead fit a support vector classifier using 2p features
#
# $X_1,X_1^2,X_2,X_2^2,\cdots,X_p,X_p^2.$
#
# Then (9.12)–(9.15) would become
#
# $maximize_{\beta_0,\beta_{11},\beta_{12},\cdots,\beta_{p1},\beta_{p2},\epsilon_1,\cdots,\epsilon_n}M\ (9.16)$
#
# $subject\ to\ y_i(\beta_0+\sum_{j=1}^p\beta_{j1}x_{ij}+\sum_{j=1}^p\beta_{j2}x_{ij}^2) \ge M(1-\epsilon_i),$
#
# $\epsilon_i \ge 0,\sum_{i=1}^n\epsilon_i \le C,\sum_{j=1}^p\sum_{k=1}^2\beta_{jk}^2=1.$
#
# ### 9.3.2 The Support Vector Machine
# The **support vector machine** (SVM) is an extension of the support vector classifier that results from enlarging the feature space in a specific way, using **kernels**.
#
# The inner product of two r-vectors a and b is defined as $<a,b>=\sum_{i=1}^r a_ib_i$. Thus the inner product of two observations $x_i,x_i'$ is given by
#
# $<x_i,x_i'>=\sum_{j=1}^p x_{ij}x_{i'j}.\ (9.17)$
#
# It can be shown that
#
# - The linear support vector classifier can be represented as $f(x)=\beta_0+\sum_{i=1}^n \alpha_i<x,x_i>,\ (9.18)$,
#     - where there are n parameters $\alpha_i, i = 1, \cdots, n$, one per training observation.
# - To estimate the parameters $\alpha_1,\cdots,\alpha_n$ and $\beta_0$, all we need are the $\binom{n}{2}$ inner products $<x_i, x_{i'}>$ between all pairs of training observations.
#
# Notice that in (9.18), in order to evaluate the function f(x), we need to compute the inner product between the new point x and each of the training points $x_i$. However, it turns out that $\alpha_i$ is nonzero only for the support vectors in the solution—that is, if a training observation is not a support vector, then its $\alpha_i$ equals zero. So if S is the collection of indices of these support points, we can rewrite any solution function of the form (9.18) as
#
# $f(x)=\beta_0+\sum_{i \in S}\alpha_i<x,x_i>,\ (9.19)$
#
# which typically involves far fewer terms than in (9.18).
#
# Now suppose that every time the inner product (9.17) appears in the representation (9.18), or in a calculation of the solution for the support vector classifier, we replace it with a **generalization** of the inner product of the form
#
# $K(x_i,x_i'),\ (9.20)$
#
# where K is some function that we will refer to as a **kernel**. A kernel is a function that quantifies the similarity of two observations. For instance, we could simply take
#
# $K(x_i,x_i')=\sum_{j=1}^p x_{ij}x_{i'j},\ (9.21)$
#
# which would just give us back the support vector classifier. Equation 9.21 is known as a **linear** kernel because the support vector classifier is linear in the features; the linear kernel essentially quantifies the similarity of a pair of observations using Pearson (standard) correlation. But one could instead choose an other form for (9.20). For instance, one could replace every instance of $\sum_{j=1}^p x_{ij}x_{i'j}$ with the quantity
#
# $K(x_i,x_{i'})=(1+\sum_{j=1}^p x_{ij}x_{i'j})^d\ (9.22)$
#
# This is known as a **polynomial kernel** of degree d, where d is a positive integer.
#
# When the support vector classifier is combined with a non-linear kernel such as (9.22), the resulting classifier is known as a **support vector machine**. Note that in this case the (non-linear) function has the form
#
# $f(x)=\beta_0+\sum_{i \in S}\alpha_iK(x,x_i).\ (9.23)$
#
# Another popular choice is the radial kernel, which takes the form
#
# $K(x_i,x_{i'})=exp(-\gamma\sum_{j=1}^p(x_{ij}-x_{i'j})^2).\ (9.24)$
#
# ![](http://ou8qjsj0m.bkt.clouddn.com//17-12-28/89746934.jpg)
#
# ### 9.3.3 An Application to the Heart Disease Data
# ![](http://ou8qjsj0m.bkt.clouddn.com//17-12-28/60861841.jpg)
#
# ## 9.4 SVMs with More than Two Classes
# ### 9.4.1 One-Versus-One Classification
# A one-versus-one or all-pairs approach constructs $\binom{K}{2}$
# SVMs, each of which compares a pair of classes.
# ### 9.4.2 One-Versus-All Classification
# We fit K SVMs, each time comparing one of all the K classes to the remaining K−1 classes.
#
# ## 9.5 Relationship to Logistic Regression
# It turns out that one can rewrite the criterion (9.12)–(9.15) for fitting the support vector classifier $f(X)=\beta_0+\beta_1X_1+\cdots+\beta_pX_p$ as
#
# $minimize_{\beta_0,\beta_1,\cdots,\beta_p}\{\sum_{i=1}^n max[0,1-y_if(x_i)]+\lambda\sum_{j=1}^p\beta_j^2\},\ (9.25)$
#
# where λ is a nonnegative tuning parameter. When λ is large then β1, . . . , βp are small, more violations to the margin are tolerated, and a low-variance but high-bias classifier will result. When λ is small then few violations to the margin will occur; this amounts to a high-variance but low-bias classifier.
#
# Now (9.25) takes the “Loss + Penalty” form that we have seen repeatedly throughout this book:
#
# $minimize_{\beta_0,\beta_1,\cdots,\beta_p}\{L(X,y,\beta)+\lambda P(\beta)\}.\ (9.26)$

# %% [markdown]
# ## 9.6 Lab: Support Vector Machines
# ### 9.6.1 Support Vector Classifier
# We begin by generating the observations, which belong to two classes, and checking whether the classes are linearly separable.

# %%
set.seed(1)
x=matrix(rnorm(20*2), ncol=2)
y=c(rep(-1,10), rep(1,10))
x[y==1,]=x[y==1,] + 1
plot(x, col=(3-y))
# Out:
# plot without title

# %% [markdown]
# We now create a data frame with the response coded as a factor.

# %%
dat=data.frame(x=x, y=as.factor(y))
library(e1071)
svmfit=svm(y~., data=dat, kernel="linear", cost=10, scale=FALSE)
plot(svmfit , dat)
# Out:
# Plot with title “SVM classification plot”

# %% [markdown]
# We see here that there are seven support vectors. We can determine their identities as follows:

# %%
svmfit$index
# Out:
# [1]  1  2  5  7 14 16 17

# %%
summary(svmfit)
# Out:
# Call:
# svm(formula = y ~ ., data = dat, kernel = "linear", cost = 10, scale = FALSE)
#
#
# Parameters:
#    SVM-Type:  C-classification
#  SVM-Kernel:  linear
#        cost:  10
#       gamma:  0.5
#
# Number of Support Vectors:  7
#
#  ( 4 3 )
#
#
# Number of Classes:  2
#
# Levels:
#  -1 1

# %% [markdown]
# What if we instead used a smaller value of the cost parameter?

# %%
svmfit=svm(y~., data=dat, kernel="linear", cost=0.1, scale=FALSE)
plot(svmfit , dat)
svmfit$index
# Out:
#  [1]  1  2  3  4  5  7  9 10 12 13 14 15 16 17 18 20
# Plot with title “SVM classification plot”

# %% [markdown]
# Now that a smaller value of the cost parameter is being used, we obtain a larger number of support vectors, because the margin is now wider.
#
# The e1071 library includes a built-in function, **tune()**, to perform cross-validation.

# %%
set.seed(1)
tune.out=tune(svm,y~.,data=dat,kernel="linear",ranges=list(cost=c(0.001, 0.01, 0.1, 1,5,10,100)))
summary(tune.out)
# Out:
# Parameter tuning of ‘svm’:
#
# - sampling method: 10-fold cross validation
#
# - best parameters:
#  cost
#   0.1
#
# - best performance: 0.1
#
# - Detailed performance results:
#    cost error dispersion
# 1 1e-03  0.70  0.4216370
# 2 1e-02  0.70  0.4216370
# 3 1e-01  0.10  0.2108185
# 4 1e+00  0.15  0.2415229
# 5 5e+00  0.15  0.2415229
# 6 1e+01  0.15  0.2415229
# 7 1e+02  0.15  0.2415229

# %%
bestmod=tune.out$best.model
summary(bestmod)
# Out:
# Call:
# best.tune(method = svm, train.x = y ~ ., data = dat, ranges = list(cost = c(0.001,
#     0.01, 0.1, 1, 5, 10, 100)), kernel = "linear")
#
#
# Parameters:
#    SVM-Type:  C-classification
#  SVM-Kernel:  linear
#        cost:  0.1
#       gamma:  0.5
#
# Number of Support Vectors:  16
#
#  ( 8 8 )
#
#
# Number of Classes:  2
#
# Levels:
#  -1 1

# %% [markdown]
# The **predict()** function can be used to predict the class label on a set of test observations, at any given value of the cost parameter.

# %%
xtest=matrix(rnorm(20*2), ncol=2)
ytest=sample(c(-1,1), 20, rep=TRUE)
xtest[ytest==1,]=xtest[ytest==1,] + 1
testdat=data.frame(x=xtest, y=as.factor(ytest))
ypred=predict(bestmod,testdat)
table(predict=ypred, truth=testdat$y)
# Out:
#        truth
# predict -1  1
#      -1 11  1
#      1   0  8

# %%
svmfit=svm(y~., data=dat, kernel="linear", cost=.01, scale=FALSE)
ypred=predict(svmfit ,testdat)
table(predict=ypred, truth=testdat$y)
# Out:
#        truth
# predict -1  1
#      -1 11  2
#      1   0  7

# %% [markdown]
# We first further separate the two classes in our simulated data so that they are linearly separable:

# %%
x[y==1,]=x[y==1,]+0.5
plot(x, col=(y+5)/2, pch=19)
# Out:
# plot without title

# %% [markdown]
# We fit the support vector classifier and plot the resulting hyperplane, using a very large value of cost so that no observations are misclassified.

# %%
dat=data.frame(x=x,y=as.factor(y))
svmfit=svm(y~., data=dat, kernel="linear", cost=1e5)
summary(svmfit)
# Out:
# Call:
# svm(formula = y ~ ., data = dat, kernel = "linear", cost = 1e+05)
#
#
# Parameters:
#    SVM-Type:  C-classification
#  SVM-Kernel:  linear
#        cost:  1e+05
#       gamma:  0.5
#
# Number of Support Vectors:  3
#
#  ( 1 2 )
#
#
# Number of Classes:  2
#
# Levels:
#  -1 1

# %% [markdown]
# It seems likely that this model will perform poorly on test data. We now try a smaller value of cost:

# %%
svmfit=svm(y~., data=dat, kernel="linear", cost=1)
summary(svmfit)
plot(svmfit,dat)
# Out:
# Call:
# svm(formula = y ~ ., data = dat, kernel = "linear", cost = 1)
#
#
# Parameters:
#    SVM-Type:  C-classification
#  SVM-Kernel:  linear
#        cost:  1
#       gamma:  0.5
#
# Number of Support Vectors:  7
#
#  ( 4 3 )
#
#
# Number of Classes:  2
#
# Levels:
#  -1 1
# Plot with title “SVM classification plot”

# %% [markdown]
# ### 9.6.2 Support Vector Machine
# We first generate some data with a non-linear class boundary, as follows:

# %%
set.seed(1)
x=matrix(rnorm(200*2), ncol=2)
x[1:100,]=x[1:100,]+2
x[101:150,]=x[101:150,]-2
y=c(rep(1,150),rep(2,50))
dat=data.frame(x=x,y=as.factor(y))
plot(x, col=y)
# Out:
# plot without title

# %% [markdown]
# We then fit the training data using the svm() function with a radial kernel and $\gamma = 1$:

# %%
train=sample(200,100)
svmfit=svm(y~., data=dat[train,], kernel="radial", gamma=1, cost=1)
plot(svmfit, dat[train ,])
# Out:
# Plot with title “SVM classification plot”

# %%
summary(svmfit)
# Out:
# Call:
# svm(formula = y ~ ., data = dat[train, ], kernel = "radial", gamma = 1,
#     cost = 1)
#
#
# Parameters:
#    SVM-Type:  C-classification
#  SVM-Kernel:  radial
#        cost:  1
#       gamma:  1
#
# Number of Support Vectors:  37
#
#  ( 17 20 )
#
#
# Number of Classes:  2
#
# Levels:
#  1 2

# %% [markdown]
# If we increase the value of cost, we can reduce the number of training errors. However, this comes at the price of a more irregular decision boundary that seems to be at risk of overfitting the data.

# %%
svmfit=svm(y~., data=dat[train,], kernel="radial", gamma=1, cost=1e5)
plot(svmfit,dat[train,])
# Out:
# Plot with title “SVM classification plot”

# %% [markdown]
# We can perform cross-validation using tune() to select the best choice of $\gamma$ and cost for an SVM with a radial kernel:

# %%
set.seed(1)
tune.out=tune(svm, y~., data=dat[train,], kernel="radial", ranges=list(cost=c(0.1,1,10,100,1000), gamma=c(0.5,1,2,3,4) ))
summary(tune.out)
# Out:
# Parameter tuning of ‘svm’:
#
# - sampling method: 10-fold cross validation
#
# - best parameters:
#  cost gamma
#     1     2
#
# - best performance: 0.12
#
# - Detailed performance results:
#     cost gamma error dispersion
# 1  1e-01   0.5  0.27 0.11595018
# 2  1e+00   0.5  0.13 0.08232726
# 3  1e+01   0.5  0.15 0.07071068
# 4  1e+02   0.5  0.17 0.08232726
# 5  1e+03   0.5  0.21 0.09944289
# 6  1e-01   1.0  0.25 0.13540064
# 7  1e+00   1.0  0.13 0.08232726
# 8  1e+01   1.0  0.16 0.06992059
# 9  1e+02   1.0  0.20 0.09428090
# 10 1e+03   1.0  0.20 0.08164966
# 11 1e-01   2.0  0.25 0.12692955
# 12 1e+00   2.0  0.12 0.09189366
# 13 1e+01   2.0  0.17 0.09486833
# 14 1e+02   2.0  0.19 0.09944289
# 15 1e+03   2.0  0.20 0.09428090
# 16 1e-01   3.0  0.27 0.11595018
# 17 1e+00   3.0  0.13 0.09486833
# 18 1e+01   3.0  0.18 0.10327956
# 19 1e+02   3.0  0.21 0.08755950
# 20 1e+03   3.0  0.22 0.10327956
# 21 1e-01   4.0  0.27 0.11595018
# 22 1e+00   4.0  0.15 0.10801234
# ...

# %%
table(true=dat[-train,"y"], pred=predict(tune.out$best.model, newdata=dat[-train ,]))
# Out:
#     pred
# true  1  2
#    1 74  3
#    2  7 16

# %% [markdown]
# ### 9.6.3 ROC Curves

# %%
library(ROCR)
rocplot=function(pred, truth, ...) {
    predob = prediction(pred, truth)
    perf = performance (predob , "tpr", "fpr")
    plot(perf ,...)
}

# %%
svmfit.opt=svm(y~., data=dat[train,], kernel="radial", gamma=2, cost=1,decision.values=T)
fitted=attributes(predict(svmfit.opt,dat[train,],decision.values=TRUE))$decision.values
par(mfrow=c(1,2))
rocplot(fitted, dat[train, "y"], main="Training Data")
# Out:
# Plot with title “Training Data”

# %% [markdown]
# By increasing $\gamma$ we can produce a more flexible fit and generate further improvements in accuracy.

# %%
svmfit.flex=svm(y~., data=dat[train,], kernel="radial", gamma=50, cost=1, decision.values=T)
fitted=attributes(predict(svmfit.flex,dat[train,],decision.values=T))$decision.values
rocplot(fitted, dat[train, "y"], col="red")
# Out:
# plot without title

# %% [markdown]
# ### 9.6.4 SVM with Multiple Classes
# We explore that setting here by generating a third class of obser- vations.

# %%
set.seed(1)
x=rbind(x, matrix(rnorm(50*2), ncol=2))
y=c(y, rep(0,50))
x[y==0,2]=x[y==0,2]+2
dat=data.frame(x=x, y=as.factor(y))
par(mfrow=c(1,1))
plot(x,col=(y+1))
# Out:
# plot without title

# %%
svmfit=svm(y~., data=dat, kernel="radial", cost=10, gamma=1)
plot(svmfit, dat)
# Out:
# Plot with title “SVM classification plot”

# %% [markdown]
# ### 9.6.5 Application to Gene Expression Data

# %%
library(ISLR)
names(Khan)
# Out:
# [1] "xtrain" "xtest"  "ytrain" "ytest"

# %%
dim(Khan$xtrain )
# Out:
# [1]   63 2308

# %%
dim(Khan$xtest)
# Out:
# [1]   20 2308

# %%
length(Khan$ytrain)
# Out:
# [1] 63

# %%
length(Khan$ytest)
# Out:
# [1] 20

# %% [markdown]
# This data set consists of expression measurements for 2,308 genes. The training and test sets consist of 63 and 20 observations respectively.

# %%
table(Khan$ytrain)
# Out:
#  1  2  3  4
#  8 23 12 20

# %%
table(Khan$ytest)
# Out:
# 1 2 3 4
# 3 6 6 5

# %% [markdown]
# We will use a support vector approach to predict cancer subtype using gene expression measurements. In this data set, there are a very large number of features relative to the number of observations. This suggests that we should use a linear kernel, because the additional flexibility that will result from using a polynomial or radial kernel is unnecessary.

# %%
dat=data.frame(x=Khan$xtrain , y=as.factor(Khan$ytrain))
out=svm(y~., data=dat, kernel="linear", cost=10)
summary(out)
# Out:
# Call:
# svm(formula = y ~ ., data = dat, kernel = "linear", cost = 10)
#
#
# Parameters:
#    SVM-Type:  C-classification
#  SVM-Kernel:  linear
#        cost:  10
#       gamma:  0.0004332756
#
# Number of Support Vectors:  58
#
#  ( 20 20 11 7 )
#
#
# Number of Classes:  4
#
# Levels:
#  1 2 3 4

# %%
dat.te=data.frame(x=Khan$xtest, y=as.factor(Khan$ytest))
pred.te=predict(out, newdata=dat.te)
table(pred.te, dat.te$y)
# Out:
#
# pred.te 1 2 3 4
#       1 3 0 0 0
#       2 0 6 2 0
#       3 0 0 4 0
#       4 0 0 0 5

# %% [markdown]
# We see that using cost=10 yields two test set errors on this data.
