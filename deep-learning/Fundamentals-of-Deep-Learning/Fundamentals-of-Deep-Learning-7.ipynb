# %% [markdown]
# # Fundamentals of Deep Learning
# ## 目录
# - Chapter 7. Models for Sequence Analysis
#     - Analyzing Variable-Length Inputs
#     - Tackling seq2seq with Neural N-Grams
#     - Implementing a Part-of-Speech Tagger
#     - Dependency Parsing and SyntaxNet
#     - Beam Search and Global Normalization
#     - A Case for Stateful Deep Learning Models
#     - Recurrent Neural Networks
#     - Long Short-Term Memory (LSTM) Units
#     - Implementing a Sentiment Analysis Model
#     - Solving seq2seq Tasks with Recurrent Neural Networks
#     - Augmenting Recurrent Networks with Attention
#
#
# ## Analyzing Variable-Length Inputs
# In Figure 7-1, we illustrate how our feed-forward neural networks break when analyzing sequences. If the sequence is the same size as the input layer, the model can perform as we expect it to. It’s even possible to deal with smaller inputs by **padding zeros to the end of the input until it’s the appropriate length**. However, the moment the input exceeds the size of the input layer, naively using the feedforward network no longer works.
#
# ![7-1](https://www.safaribooksonline.com/library/view/fundamentals-of-deep/9781491925607/assets/fodl_0701.png)
#
# Figure 7-1. Feed-forward networks thrive on fixed input size problems. Zero padding can address the handling of smaller inputs, but when naively utilized, these models break when inputs exceed the fixed input size.
#
# ## Tackling seq2seq with Neural N-Grams
# In this section, we’ll begin exploring a feed-forward neural network architecture that can process a body of text and produce a sequence of `part-of-speech (POS)` tags. An example of this is shown in Figure 7-2.
#
# ![7-2](https://www.safaribooksonline.com/library/view/fundamentals-of-deep/9781491925607/assets/fodl_0702.png)
#
# Figure 7-2. An example of an accurate POS parse of an English sentence
#
# We can predict each POS tag one at a time by using a fixed-length subsequence. In particular, we utilize the subsequence starting from the word of interest and extending n words into the past. This neural n-gram strategy is depicted in Figure 7-3.
#
# ![7-3](https://www.safaribooksonline.com/library/view/fundamentals-of-deep/9781491925607/assets/fodl_0703.png)
#
# Figure 7-3. Using a feed-forward network to perform seq2seq when we can ignore long-term dependencies
#
# Specifically, when we predict the POS tag for the $i^{th}$ word in the input, we utilize the $i - n + 1^{st}, i - n + 2^{nd}, \cdots, i^{th}$ words as the input. We’ll refer to this subsequence as the `context window`.
#
# ## Implementing a Part-of-Speech Tagger
# On a high level, the network consists of an input layer that leverages a 3-gram context window. We’ll utilize word embeddings that are 300-dimensional, resulting in a context window of size 900. The feed-forward network will have two hidden layers of size 512 neurons and 256 neurons, respectively. Finally, the output layer will be a softmax calculating the probability distribution of the POS tag output over a space of 44 possible tags.
#
# The tricky part of building the POS tagger is in preparing the dataset. We’ll leverage pretrained word embeddings generated from Google News. It includes vectors for 3 million words and phrases and was trained on roughly 100 billion words.
#
# As we mentioned, the gensim model contains three million words, which is larger than our dataset. For the sake of efficiency, we’ll selectively cache word vectors for words in our dataset and discard everything else. To figure out which words we’d like to cache, let’s download the POS dataset from the CoNLL-2000 task.

# %%
# !head data/pos.train.txt
# Out:
# Confidence NN
# in IN
# the DT
# pound NN
# is VBZ
# widely RB
# expected VBN
# to TO
# take VB
# another DT

# %%
# !head data/pos.test.txt
# Out:
# Rockwell NNP
# International NNP
# Corp. NNP
# 's POS
# Tulsa NNP
# unit NN
# said VBD
# it PRP
# signed VBD
# a DT

# %%
# !python feedforward_pos.py 3
# Out:
# LOADING PRETRAINED WORD2VEC MODEL...
# Using a 3-gram model
# 2017-11-27 13:20:32.525448: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.1 instructions, but these are available on your machine and could speed up CPU computations.
# 2017-11-27 13:20:32.525474: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2017-11-27 13:20:32.525484: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# 2017-11-27 13:20:32.525492: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX2 instructions, but these are available on your machine and could speed up CPU computations.
# 2017-11-27 13:20:32.525499: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use FMA instructions, but these are available on your machine and could speed up CPU computations.
# WARNING:tensorflow:From feedforward_pos.py:128: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Epoch: 0001 cost = 3.148425088
# Validation Error: 0.209537446499
# Then		``
# the		DT
# woman		NN
# ,		,
# after		SYM
# grabbing		VBG
# her		PRP$
# umbrella		NN
# ,		,
# went		SYM
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		PDT
# Epoch: 0002 cost = 2.965082352
# Validation Error: 0.191296637058
# Then		``
# the		DT
# woman		NN
# ,		,
# after		SYM
# grabbing		VBG
# her		PRP$
# umbrella		NN
# ,		,
# went		SYM
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		NN
# .		PDT
# Epoch: 0003 cost = 2.910341188
# Validation Error: 0.144409835339
# Then		``
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP$
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		JJ
# .		PDT
# Epoch: 0004 cost = 2.868964075
# Validation Error: 0.110666453838
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP$
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		NN
# .		PDT
# Epoch: 0005 cost = 2.855041752
# Validation Error: 0.102220058441
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP$
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		JJ
# .		PDT
# Epoch: 0006 cost = 2.848913494
# Validation Error: 0.0979021191597
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP$
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		NN
# .		PDT
# Epoch: 0007 cost = 2.845357339
# Validation Error: 0.0840213894844
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP$
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		NN
# .		PDT
# Epoch: 0008 cost = 2.842793162
# Validation Error: 0.069256067276
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP$
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		NN
# .		PDT
# Epoch: 0009 cost = 2.840920654
# Validation Error: 0.0647906064987
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP$
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		NN
# .		.
# Epoch: 0010 cost = 2.839460365
# Validation Error: 0.0636742711067
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP$
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		JJ
# .		.
# Epoch: 0011 cost = 2.838145334
# Validation Error: 0.05638641119
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0012 cost = 2.837352455
# Validation Error: 0.0600935220718
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0013 cost = 2.836188683
# Validation Error: 0.058029294014
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		NN
# .		.
# Epoch: 0014 cost = 2.835757539
# Validation Error: 0.0606622099876
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP$
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		NN
# .		.
# Epoch: 0015 cost = 2.835224603
# Validation Error: 0.0585137605667
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP$
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0016 cost = 2.834578492
# Validation Error: 0.058218896389
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP$
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		NN
# .		.
# Epoch: 0017 cost = 2.834032812
# Validation Error: 0.0580503940582
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0018 cost = 2.833315874
# Validation Error: 0.0579029321671
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP$
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		NN
# .		.
# Epoch: 0019 cost = 2.831755641
# Validation Error: 0.057313144207
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP$
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		NN
# .		.
# Epoch: 0020 cost = 2.831599839
# Validation Error: 0.056912958622
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0021 cost = 2.831207507
# Validation Error: 0.0561757683754
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		NN
# .		.
# Epoch: 0022 cost = 2.831050545
# Validation Error: 0.0568497776985
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		NN
# .		.
# Epoch: 0023 cost = 2.830699176
# Validation Error: 0.054364323616
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		NN
# .		.
# Epoch: 0024 cost = 2.830408062
# Validation Error: 0.0559019446373
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP$
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		NN
# .		.
# Epoch: 0025 cost = 2.830202650
# Validation Error: 0.0555438399315
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP$
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0026 cost = 2.830039076
# Validation Error: 0.0561757683754
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		NN
# .		.
# Epoch: 0027 cost = 2.829921745
# Validation Error: 0.0556281208992
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP$
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		NN
# .		.
# Epoch: 0028 cost = 2.829719226
# Validation Error: 0.0544485449791
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP$
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		NN
# .		.
# Epoch: 0029 cost = 2.829595877
# Validation Error: 0.0556281208992
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		NN
# .		.
# Epoch: 0030 cost = 2.829521546
# Validation Error: 0.0560283064842
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP$
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0031 cost = 2.829099114
# Validation Error: 0.0570182800293
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP$
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0032 cost = 2.829160170
# Validation Error: 0.0528056025505
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		NN
# .		.
# Epoch: 0033 cost = 2.828931762
# Validation Error: 0.0538377165794
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		NN
# .		.
# Epoch: 0034 cost = 2.828867324
# Validation Error: 0.0537323951721
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP$
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		NN
# .		.
# Epoch: 0035 cost = 2.828684661
# Validation Error: 0.0541326403618
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP$
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		NN
# .		.
# Epoch: 0036 cost = 2.828588095
# Validation Error: 0.0465077161789
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP$
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		NN
# .		.
# Epoch: 0037 cost = 2.828490250
# Validation Error: 0.0468236804008
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP$
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		NN
# .		.
# Epoch: 0038 cost = 2.828296700
# Validation Error: 0.0469079017639
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP$
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		NN
# .		.
# Epoch: 0039 cost = 2.828132550
# Validation Error: 0.0477083325386
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP$
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0040 cost = 2.828140730
# Validation Error: 0.0470342636108
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP$
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		NN
# .		.
# Epoch: 0041 cost = 2.828018475
# Validation Error: 0.0461285710335
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP$
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		NN
# .		.
# Epoch: 0042 cost = 2.827906793
# Validation Error: 0.0462549328804
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP$
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		NN
# .		.
# Epoch: 0043 cost = 2.827970759
# Validation Error: 0.045875787735
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP$
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0044 cost = 2.827920870
# Validation Error: 0.0446541309357
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP$
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0045 cost = 2.827627038
# Validation Error: 0.0450332760811
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP$
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0046 cost = 2.827649736
# Validation Error: 0.0457494258881
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		NN
# .		.
# Epoch: 0047 cost = 2.827614046
# Validation Error: 0.0449069142342
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP$
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		NN
# .		.
# Epoch: 0048 cost = 2.827432558
# Validation Error: 0.0454966425896
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		NN
# .		.
# Epoch: 0049 cost = 2.827492118
# Validation Error: 0.0441486239433
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		NN
# .		.
# Epoch: 0050 cost = 2.827333513
# Validation Error: 0.0465287566185
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		NN
# .		.
# Epoch: 0051 cost = 2.827431312
# Validation Error: 0.0452228784561
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		NN
# .		.
# Epoch: 0052 cost = 2.827160523
# Validation Error: 0.044443488121
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		NN
# .		.
# Epoch: 0053 cost = 2.827200904
# Validation Error: 0.0443381667137
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		NN
# .		.
# Epoch: 0054 cost = 2.826973383
# Validation Error: 0.0438748002052
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		NN
# .		.
# Epoch: 0055 cost = 2.826937586
# Validation Error: 0.0432007908821
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		NN
# .		.
# Epoch: 0056 cost = 2.826934599
# Validation Error: 0.0447384119034
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		NN
# .		.
# Epoch: 0057 cost = 2.826854699
# Validation Error: 0.0428426861763
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		NN
# .		.
# Epoch: 0058 cost = 2.826912204
# Validation Error: 0.0452228784561
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		NN
# .		.
# Epoch: 0059 cost = 2.826798661
# Validation Error: 0.0434324741364
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0060 cost = 2.826698262
# Validation Error: 0.0441486239433
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		NN
# .		.
# Epoch: 0061 cost = 2.826745165
# Validation Error: 0.0436009764671
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0062 cost = 2.826675772
# Validation Error: 0.0444224476814
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0063 cost = 2.826712624
# Validation Error: 0.0434746146202
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0064 cost = 2.826644147
# Validation Error: 0.0445488095284
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		NN
# .		.
# Epoch: 0065 cost = 2.826488504
# Validation Error: 0.0434324741364
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		NN
# .		.
# Epoch: 0066 cost = 2.826623246
# Validation Error: 0.0449700951576
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		NN
# .		.
# Epoch: 0067 cost = 2.826485328
# Validation Error: 0.0445488095284
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		NN
# .		.
# Epoch: 0068 cost = 2.826452775
# Validation Error: 0.0430743694305
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		NN
# .		.
# Epoch: 0069 cost = 2.826389728
# Validation Error: 0.0440222620964
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		NN
# .		.
# Epoch: 0070 cost = 2.826310395
# Validation Error: 0.0434746146202
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		NN
# .		.
# Epoch: 0071 cost = 2.826463094
# Validation Error: 0.0426952838898
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		NN
# .		.
# Epoch: 0072 cost = 2.826277182
# Validation Error: 0.0434324741364
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0073 cost = 2.826382959
# Validation Error: 0.0437273383141
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0074 cost = 2.826200092
# Validation Error: 0.0428637862206
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0075 cost = 2.826212260
# Validation Error: 0.0434746146202
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		NN
# .		.
# Epoch: 0076 cost = 2.826212376
# Validation Error: 0.0440854430199
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0077 cost = 2.826156251
# Validation Error: 0.0435588359833
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0078 cost = 2.826007705
# Validation Error: 0.0435588359833
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0079 cost = 2.826108511
# Validation Error: 0.0431376099586
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0080 cost = 2.826068944
# Validation Error: 0.0433903336525
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0081 cost = 2.826071527
# Validation Error: 0.0438958406448
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0082 cost = 2.825937903
# Validation Error: 0.0441064834595
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP$
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0083 cost = 2.826017416
# Validation Error: 0.0434746146202
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP$
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0084 cost = 2.825893637
# Validation Error: 0.0440222620964
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP$
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0085 cost = 2.825783524
# Validation Error: 0.0430954694748
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0086 cost = 2.825855624
# Validation Error: 0.0430322885513
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0087 cost = 2.825811590
# Validation Error: 0.0419791340828
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP$
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0088 cost = 2.825735940
# Validation Error: 0.043242931366
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP$
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0089 cost = 2.825727497
# Validation Error: 0.0438537597656
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP$
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		NN
# .		.
# Epoch: 0090 cost = 2.825745257
# Validation Error: 0.0430533289909
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0091 cost = 2.825699678
# Validation Error: 0.0432007908821
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		NN
# .		.
# Epoch: 0092 cost = 2.825709790
# Validation Error: 0.0428005456924
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0093 cost = 2.825691494
# Validation Error: 0.0432850122452
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0094 cost = 2.825666268
# Validation Error: 0.0416631698608
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0095 cost = 2.825596328
# Validation Error: 0.0427795052528
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0096 cost = 2.825621327
# Validation Error: 0.0433481931686
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0097 cost = 2.825433420
# Validation Error: 0.0428216457367
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0098 cost = 2.825460029
# Validation Error: 0.0423582196236
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0099 cost = 2.825552959
# Validation Error: 0.0425267219543
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0100 cost = 2.825550255
# Validation Error: 0.0416420698166
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		NN
# .		.
# Epoch: 0101 cost = 2.825469849
# Validation Error: 0.0430111885071
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		NN
# .		.
# Epoch: 0102 cost = 2.825512510
# Validation Error: 0.0434324741364
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0103 cost = 2.825443740
# Validation Error: 0.0416420698166
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0104 cost = 2.825400960
# Validation Error: 0.0429901480675
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		NN
# .		.
# Epoch: 0105 cost = 2.825469664
# Validation Error: 0.0438748002052
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0106 cost = 2.825332360
# Validation Error: 0.0415367484093
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		NN
# .		.
# Epoch: 0107 cost = 2.825410363
# Validation Error: 0.042337179184
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		NN
# .		.
# Epoch: 0108 cost = 2.825340894
# Validation Error: 0.0421265363693
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0109 cost = 2.825435774
# Validation Error: 0.0421686768532
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0110 cost = 2.825292507
# Validation Error: 0.0425899624825
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0111 cost = 2.825309690
# Validation Error: 0.0430743694305
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0112 cost = 2.825291100
# Validation Error: 0.0421897172928
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0113 cost = 2.825316727
# Validation Error: 0.0424003601074
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		NN
# .		.
# Epoch: 0114 cost = 2.825261910
# Validation Error: 0.0420423150063
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		NN
# .		.
# Epoch: 0115 cost = 2.825192440
# Validation Error: 0.0430111885071
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		NN
# .		.
# Epoch: 0116 cost = 2.825233853
# Validation Error: 0.0412840247154
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		NN
# .		.
# Epoch: 0117 cost = 2.825271450
# Validation Error: 0.0426531434059
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		NN
# .		.
# Epoch: 0118 cost = 2.825246796
# Validation Error: 0.0418316721916
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		NN
# .		.
# Epoch: 0119 cost = 2.825162325
# Validation Error: 0.043453514576
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		NN
# .		.
# Epoch: 0120 cost = 2.825189689
# Validation Error: 0.0422739982605
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0121 cost = 2.825213468
# Validation Error: 0.0421054959297
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		NN
# .		.
# Epoch: 0122 cost = 2.825185883
# Validation Error: 0.0427584648132
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		NN
# .		.
# Epoch: 0123 cost = 2.825189354
# Validation Error: 0.0426531434059
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0124 cost = 2.825153132
# Validation Error: 0.042737364769
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0125 cost = 2.825150287
# Validation Error: 0.0428637862206
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0126 cost = 2.825049194
# Validation Error: 0.0442749857903
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0127 cost = 2.825084392
# Validation Error: 0.0433061122894
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0128 cost = 2.825032398
# Validation Error: 0.0433061122894
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0129 cost = 2.825080368
# Validation Error: 0.042021214962
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		NN
# .		.
# Epoch: 0130 cost = 2.825149320
# Validation Error: 0.0435588359833
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		NN
# .		.
# Epoch: 0131 cost = 2.824963305
# Validation Error: 0.0426741838455
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0132 cost = 2.824988477
# Validation Error: 0.0422950387001
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		NN
# .		.
# Epoch: 0133 cost = 2.825078471
# Validation Error: 0.0431586503983
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0134 cost = 2.825042798
# Validation Error: 0.0423582196236
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0135 cost = 2.824974248
# Validation Error: 0.0424635410309
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0136 cost = 2.824987725
# Validation Error: 0.0438537597656
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0137 cost = 2.825033182
# Validation Error: 0.0427163243294
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0138 cost = 2.824966088
# Validation Error: 0.0425688624382
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0139 cost = 2.824944321
# Validation Error: 0.0428637862206
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		NN
# .		.
# Epoch: 0140 cost = 2.825027825
# Validation Error: 0.0428637862206
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0141 cost = 2.824980792
# Validation Error: 0.0428848266602
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0142 cost = 2.824915660
# Validation Error: 0.0419791340828
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0143 cost = 2.824929436
# Validation Error: 0.0431586503983
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		NN
# .		.
# Epoch: 0144 cost = 2.824886595
# Validation Error: 0.0427584648132
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0145 cost = 2.824959443
# Validation Error: 0.0424846410751
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0146 cost = 2.824903124
# Validation Error: 0.042021214962
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0147 cost = 2.824805492
# Validation Error: 0.0421897172928
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0148 cost = 2.824932210
# Validation Error: 0.0425688624382
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0149 cost = 2.824867349
# Validation Error: 0.042210817337
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0150 cost = 2.824797216
# Validation Error: 0.0428216457367
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0151 cost = 2.824854422
# Validation Error: 0.042210817337
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0152 cost = 2.824855430
# Validation Error: 0.0424846410751
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0153 cost = 2.824806071
# Validation Error: 0.0429691076279
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0154 cost = 2.824822859
# Validation Error: 0.042210817337
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0155 cost = 2.824772739
# Validation Error: 0.0424425005913
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0156 cost = 2.824768236
# Validation Error: 0.0425478219986
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0157 cost = 2.824787493
# Validation Error: 0.0426741838455
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0158 cost = 2.824782187
# Validation Error: 0.0425267219543
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0159 cost = 2.824795963
# Validation Error: 0.0421265363693
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		NN
# .		.
# Epoch: 0160 cost = 2.824785369
# Validation Error: 0.043327152729
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0161 cost = 2.824834550
# Validation Error: 0.042737364769
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0162 cost = 2.824809187
# Validation Error: 0.0427795052528
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0163 cost = 2.824782897
# Validation Error: 0.042021214962
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0164 cost = 2.824689402
# Validation Error: 0.0426952838898
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0165 cost = 2.824805739
# Validation Error: 0.0420843958855
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0166 cost = 2.824758977
# Validation Error: 0.0427163243294
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0167 cost = 2.824717564
# Validation Error: 0.0423161387444
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0168 cost = 2.824847383
# Validation Error: 0.0419580340385
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0169 cost = 2.824750076
# Validation Error: 0.0419580340385
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0170 cost = 2.824682103
# Validation Error: 0.0427584648132
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		NN
# .		.
# Epoch: 0171 cost = 2.824781801
# Validation Error: 0.042737364769
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0172 cost = 2.824747421
# Validation Error: 0.0416420698166
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0173 cost = 2.824724744
# Validation Error: 0.0423161387444
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0174 cost = 2.824671039
# Validation Error: 0.0417895317078
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		NN
# .		.
# Epoch: 0175 cost = 2.824704794
# Validation Error: 0.0427163243294
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		NN
# .		.
# Epoch: 0176 cost = 2.824704463
# Validation Error: 0.0425899624825
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0177 cost = 2.824734597
# Validation Error: 0.0426320433617
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		NN
# .		.
# Epoch: 0178 cost = 2.824668122
# Validation Error: 0.0421897172928
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0179 cost = 2.824699557
# Validation Error: 0.042021214962
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0180 cost = 2.824699991
# Validation Error: 0.0422528982162
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0181 cost = 2.824642013
# Validation Error: 0.041621029377
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0182 cost = 2.824603751
# Validation Error: 0.042210817337
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		NN
# .		.
# Epoch: 0183 cost = 2.824628326
# Validation Error: 0.0415578484535
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		NN
# .		.
# Epoch: 0184 cost = 2.824658003
# Validation Error: 0.0422528982162
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0185 cost = 2.824635374
# Validation Error: 0.0433061122894
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0186 cost = 2.824537350
# Validation Error: 0.0421476364136
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0187 cost = 2.824684573
# Validation Error: 0.0432007908821
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0188 cost = 2.824588208
# Validation Error: 0.0420423150063
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0189 cost = 2.824593516
# Validation Error: 0.0419580340385
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0190 cost = 2.824592027
# Validation Error: 0.0425688624382
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0191 cost = 2.824561027
# Validation Error: 0.0412418842316
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0192 cost = 2.824556317
# Validation Error: 0.0420843958855
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0193 cost = 2.824544526
# Validation Error: 0.0417895317078
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0194 cost = 2.824592036
# Validation Error: 0.0426741838455
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		NN
# .		.
# Epoch: 0195 cost = 2.824577593
# Validation Error: 0.0420423150063
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0196 cost = 2.824610565
# Validation Error: 0.0422318577766
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0197 cost = 2.824541899
# Validation Error: 0.042021214962
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0198 cost = 2.824534001
# Validation Error: 0.0425267219543
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0199 cost = 2.824559365
# Validation Error: 0.0434956550598
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0200 cost = 2.824570883
# Validation Error: 0.0426320433617
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0201 cost = 2.824536474
# Validation Error: 0.042337179184
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0202 cost = 2.824556271
# Validation Error: 0.0420843958855
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0203 cost = 2.824506854
# Validation Error: 0.0421686768532
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0204 cost = 2.824539094
# Validation Error: 0.0423582196236
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0205 cost = 2.824577346
# Validation Error: 0.0419369935989
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0206 cost = 2.824464447
# Validation Error: 0.0419580340385
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0207 cost = 2.824588684
# Validation Error: 0.0420423150063
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# ...
# Validation Error: 0.0422528982162
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP$
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		NN
# .		.
# Epoch: 0931 cost = 2.823876711
# Validation Error: 0.0418316721916
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP$
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		NN
# .		.
# Epoch: 0932 cost = 2.823884791
# Validation Error: 0.0423582196236
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP$
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		NN
# .		.
# Epoch: 0933 cost = 2.823921160
# Validation Error: 0.0428637862206
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		NN
# .		.
# Epoch: 0934 cost = 2.823916345
# Validation Error: 0.0427163243294
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		NN
# .		.
# Epoch: 0935 cost = 2.823914327
# Validation Error: 0.0428005456924
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP$
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		NN
# .		.
# Epoch: 0936 cost = 2.823876008
# Validation Error: 0.0422739982605
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		NN
# .		.
# Epoch: 0937 cost = 2.823914970
# Validation Error: 0.0421054959297
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP$
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		NN
# .		.
# Epoch: 0938 cost = 2.823908009
# Validation Error: 0.0426741838455
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP$
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		NN
# .		.
# Epoch: 0939 cost = 2.823928926
# Validation Error: 0.043327152729
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP$
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		NN
# .		.
# Epoch: 0940 cost = 2.823901741
# Validation Error: 0.0429901480675
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP$
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		NN
# .		.
# Epoch: 0941 cost = 2.823891743
# Validation Error: 0.0429901480675
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP$
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		NN
# .		.
# Epoch: 0942 cost = 2.823944435
# Validation Error: 0.0434114336967
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP$
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		NN
# .		.
# Epoch: 0943 cost = 2.823941511
# Validation Error: 0.0431586503983
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP$
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		NN
# .		.
# Epoch: 0944 cost = 2.823893246
# Validation Error: 0.0424425005913
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP$
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		NN
# .		.
# Epoch: 0945 cost = 2.823891406
# Validation Error: 0.0432007908821
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP$
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0946 cost = 2.823936920
# Validation Error: 0.0429901480675
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP$
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0947 cost = 2.823909859
# Validation Error: 0.0433692932129
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP$
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		NN
# .		.
# Epoch: 0948 cost = 2.823977226
# Validation Error: 0.0428216457367
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP$
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		NN
# .		.
# Epoch: 0949 cost = 2.823930260
# Validation Error: 0.0426952838898
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP$
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0950 cost = 2.823899951
# Validation Error: 0.042210817337
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP$
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0951 cost = 2.823883587
# Validation Error: 0.0425056815147
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP$
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0952 cost = 2.823933691
# Validation Error: 0.0433903336525
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0953 cost = 2.823917749
# Validation Error: 0.0435166954994
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		NN
# .		.
# Epoch: 0954 cost = 2.823887859
# Validation Error: 0.0433692932129
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		VB
# her		PRP$
# cash		NN
# .		.
# Epoch: 0955 cost = 2.823888536
# Validation Error: 0.0434746146202
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP$
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0956 cost = 2.823891425
# Validation Error: 0.0436009764671
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0957 cost = 2.823921778
# Validation Error: 0.0432850122452
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0958 cost = 2.823935524
# Validation Error: 0.043327152729
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP$
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0959 cost = 2.823901771
# Validation Error: 0.0426110029221
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP$
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0960 cost = 2.823897515
# Validation Error: 0.0430111885071
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP$
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0961 cost = 2.823935717
# Validation Error: 0.0431796908379
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0962 cost = 2.823897622
# Validation Error: 0.0430743694305
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0963 cost = 2.823905294
# Validation Error: 0.0430111885071
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0964 cost = 2.823931076
# Validation Error: 0.0428637862206
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP$
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0965 cost = 2.823899280
# Validation Error: 0.0431796908379
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0966 cost = 2.823900626
# Validation Error: 0.0430111885071
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP$
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0967 cost = 2.823893337
# Validation Error: 0.0438537597656
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP$
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0968 cost = 2.823969265
# Validation Error: 0.0436220169067
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP$
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0969 cost = 2.823894477
# Validation Error: 0.043242931366
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP$
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0970 cost = 2.823899804
# Validation Error: 0.042926967144
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0971 cost = 2.823905303
# Validation Error: 0.0424003601074
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP$
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0972 cost = 2.823910634
# Validation Error: 0.0425478219986
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP$
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0973 cost = 2.823905830
# Validation Error: 0.043453514576
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP$
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0974 cost = 2.823880380
# Validation Error: 0.0428848266602
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP$
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0975 cost = 2.823922023
# Validation Error: 0.0431165099144
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP$
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0976 cost = 2.823907477
# Validation Error: 0.0431376099586
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0977 cost = 2.823919873
# Validation Error: 0.0430533289909
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0978 cost = 2.823911841
# Validation Error: 0.0432639718056
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0979 cost = 2.823894675
# Validation Error: 0.0437273383141
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0980 cost = 2.823888008
# Validation Error: 0.0430743694305
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0981 cost = 2.823886460
# Validation Error: 0.042737364769
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0982 cost = 2.823886153
# Validation Error: 0.0430743694305
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0983 cost = 2.823872876
# Validation Error: 0.0431376099586
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0984 cost = 2.823893822
# Validation Error: 0.0433061122894
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0985 cost = 2.823883549
# Validation Error: 0.0428216457367
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0986 cost = 2.823880422
# Validation Error: 0.0438326597214
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0987 cost = 2.823898888
# Validation Error: 0.0430322885513
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0988 cost = 2.823882675
# Validation Error: 0.0425899624825
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP$
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0989 cost = 2.823923216
# Validation Error: 0.0430954694748
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0990 cost = 2.823889210
# Validation Error: 0.0430533289909
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0991 cost = 2.823882228
# Validation Error: 0.0426531434059
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0992 cost = 2.823921291
# Validation Error: 0.0426741838455
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0993 cost = 2.823896547
# Validation Error: 0.0429691076279
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0994 cost = 2.823906816
# Validation Error: 0.0430322885513
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0995 cost = 2.823897653
# Validation Error: 0.0426741838455
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0996 cost = 2.823891244
# Validation Error: 0.0429480075836
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0997 cost = 2.823926243
# Validation Error: 0.0428216457367
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0998 cost = 2.823889080
# Validation Error: 0.0426320433617
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 0999 cost = 2.823881331
# Validation Error: 0.0426110029221
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Epoch: 1000 cost = 2.823869209
# Validation Error: 0.0424003601074
# Then		RB
# the		DT
# woman		NN
# ,		,
# after		IN
# grabbing		VBG
# her		PRP
# umbrella		NN
# ,		,
# went		VBD
# to		TO
# the		DT
# bank		NN
# to		TO
# deposit		NN
# her		PRP$
# cash		NN
# .		.
# Optimization Finished!

# %% [markdown]
# Every epoch, we manually inspect the model by parsing the sentence: “The woman, after grabbing her umbrella, went to the bank to deposit her cash.” Within 100 epochs of training, the algorithm achieves over 96% accuracy and nearly perfectly parses the validation sentence (it makes the understandable mistake of confusing the possessive pronoun and personal pronoun tags for the first appearance of the word “her”). We’ll conclude this by including the visualizations of our model’s performance using TensorBoard in Figure 7-4.
#
# ![7-4](https://www.safaribooksonline.com/library/view/fundamentals-of-deep/9781491925607/assets/fodl_0704.png)
#
# Figure 7-4. TensorBoard visualization of our feedfoward POS tagging model
#
# ## Dependency Parsing and SyntaxNet
# The idea behind building a dependency parse tree is to map the relationships between words in a sentence. Take, for example, the dependency in Figure 7-5.
#
# ![7-5](https://www.safaribooksonline.com/library/view/fundamentals-of-deep/9781491925607/assets/fodl_0705.png)
#
# Figure 7-5. An example of a dependency parse, which generates a tree of relationships between words in a sentence
#
# One way to express a  tree as a sequence is by linearizing it. Let’s consider the examples in Figure 7-6.
#
# ![7-6](https://www.safaribooksonline.com/library/view/fundamentals-of-deep/9781491925607/assets/fodl_0706.png)
#
# Figure 7-6. We linearize two example trees, the diagrams omit edge labels for the sake of visual clarity
#
# Using this paradigm, we can take our example dependency parse and linearize it, as shown in Figure 7-7.
#
# ![7-7](https://www.safaribooksonline.com/library/view/fundamentals-of-deep/9781491925607/assets/fodl_0707.png)
#
# Figure 7-7. Linearization of the dependency parse tree example
#
# One interpretation of this seq2seq problem would be to read the input sentence and produce a sequence of tokens as an output that represents the linearization of the input’s dependency parse.
#
# To make the problem more approachable, we instead reconsider the dependency parsing task as finding a sequence of valid “actions” that generates the correct dependency parse. This technique, known as the `arc-standard system`:
#
# ![7-8](https://www.safaribooksonline.com/library/view/fundamentals-of-deep/9781491925607/assets/fodl_0708.png)
#
# Figure 7-8. At any step, we have three options: to shift a word from the buffer (blue) to the stack (green), to draw an arc from the right element to the left element (left arc), or to draw an arc from the left element to the right element (right arc)
#
# At any step, we can take one of three possible classes of actions:
#
# - SHIFT
#     - Move a word from the buffer to the front of the stack.
# - LEFT ARC
#     - Combine the two elements at the front of the stack into a single unit where the root of the rightmost element is the parent node and the root of leftmost element is the child node.
# - RIGHT ARC
#     - Combine the two elements at the front of the stack into a single unit where the root of the left element is the parent node and the root of right element is the child node.
#
# We finally terminate this process when the buffer is empty and the stack has one element in it (which represents the full dependency parse).
#
# ![7-9](https://www.safaribooksonline.com/library/view/fundamentals-of-deep/9781491925607/assets/fodl_0709.png)
#
# Figure 7-9. A sequence of actions that results in the correct dependency parse; we omit labels
#
# At every step, we take the current configuration, we vectorize the configuration by extracting a large number of features that describe the configuration (words in specific locations of the stack/buffer, specific children of the words in these locations, part of speech tags, etc.). During train time, we can feed this vector into a feed-forward network and compare its prediction of the next action to take to a gold standard decision made by a human linguist. To use this model in the wild, we can take the action that the network recommends, apply it to the configuration, and use this new configuration as the starting point for the next step (feature extraction, action prediction, and action application). This process is shown in Figure 7-10.
#
# ![7-10](https://www.safaribooksonline.com/library/view/fundamentals-of-deep/9781491925607/assets/fodl_0710.png)
#
# Figure 7-10. A neural framework for arc-standard dependency parsing
#
# Taken together, these ideas form the core for Google’s [SyntaxNet][1], the state-of-the-art open source implementation for dependency parsing.
#
# ## Beam Search and Global Normalization
# Consider the following sentence: “The complex houses married and single soldiers and their families.” The first glance pass-through is confusing. Most people interpret “complex” as an adjective, “houses” as a noun, and “married” as a past tense verb. This makes little semantic sense though, and starts to break down as the rest of the sentence is read. Instead, we realize that “complex” is a noun (as in a military complex) and that “houses” is a verb. In other words, the sentence implies that the military complex contains soldiers (who may be single or married) and their families. A **greedy version** of SyntaxNet would fail to correct the early parse mistake of considering “complex” as an adjective describing the “houses,” and therefore fail on the full version of the sentence.
#
# To remedy this shortcoming, we utilize a strategy known as `beam search`, illustrated in Figure 7-11. We generally leverage beam searches in situations like SyntaxNet, where the output of our network at a particular step influences the inputs used in future steps. The basic idea behind beam search is that **instead of greedily selecting the most probable prediction at each step, we maintain a beam of the most likely hypothesis (up to a fixed beam size b) for the sequence of the first k actions and their associated probabilities.** Beam searching can be broken up into two major phases: `expansion` and `pruning`.
#
# ![7-11](https://www.safaribooksonline.com/library/view/fundamentals-of-deep/9781491925607/assets/fodl_0711.png)
#
# During the expansion step, we take each hypothesis and consider it as a possible input to SyntaxNet. Assume SyntaxNet produces a probability distribution over a space of |A| total actions. We then compute the probability of each of the b|A| possible hypotheses for the sequence of the first k+1 actions. Then, during the pruning step, we keep only the b hypothesis out of the b|A| total options with the largest probabilities.
#
# As [Andor et al. describe in 2016][2], this process of global normalization provides both strong theoretical guarantees and clear performance gains relative to local normalization in practice. In a locally normalized network, our network is tasked with selecting the best action given a configuration. The network outputs a score that is normalized using a softmax layer. This is meant to model a probability distribution over all possible actions, provided the actions performed thus far. Our loss function attempts to force the probability distribution to the ideal output (i.e., probability 1 for the correct action and 0 for all other actions). The cross-entropy loss does a spectacular job of ensuring this for us.
#
# In a globally normalized network, our interpretation of the scores is slightly different. Instead of putting the scores through a softmax to generate a per-action probability distribution, we instead add up all the scores for a hypothesis action sequence. One way of ensuring that we select the correct hypothesis sequence is by computing this sum over all possible hypotheses and then applying a softmax layer to generate a probability distribution. We could theoretically use the same cross-entropy loss function as we used in the locally normalized network. The problem with this strategy, however, is that there is an intractably large number of possible hypothesis sequences. Even considering an average sentence length of 10 and a conservative total number of 15 possible actions—1 shift and 7 labels for each of the left and right arcs—this corresponds to 1,000,000,000,000,000 possible hypotheses.
#
# To make this problem tractable, as shown in Figure 7-12, we apply a beam search, with a fixed beam size, until we either 1) reach the end of the sentence, or 2) the correct sequence of actions is no longer contained on the beam. We then construct a loss function that tries to push the “gold standard” action sequence (highlighted in blue) as high as possible on the beam by maximizing its score relative to the other hypotheses.
#
# ![7-12](https://www.safaribooksonline.com/library/view/fundamentals-of-deep/9781491925607/assets/fodl_0712.png)
#
# Figure 7-12. We can make global normalization in SyntaxNet tractable by coupling training and beam search
#
# ## A Case for Stateful Deep Learning Models
# Sometimes, however, the task is far more complicated than finding a one-to-one mapping between input and output sequences. For example, we might want to develop a model that can consume an entire input sequence at once and then conclude if the sentiment of the entire input was positive or negative. We may want an algorithm that consumes a complex input (such as an image) and generate a sentence, one word at a time, describing the input. We may even want to translate sentences from one language to another (e.g., from English to French). In all of these instances, there’s no obvious mapping between input tokens and output tokens. Instead, the process is more like the situation in Figure 7-13.
#
# ![7-13](https://www.safaribooksonline.com/library/view/fundamentals-of-deep/9781491925607/assets/fodl_0713.png)
#
# Figure 7-13. The ideal model for sequence analysis can store information in memory over long periods of time, leading to a coherent “thought” vector that it can use to generate an answer
#
# The idea is simple. We want our model to maintain some sort of memory over the span of reading the input sequence. As it reads the input, the model should able to modify this memory bank, taking into account the information that it observes. By the time it has reached the end of the input sequence, the internal memory contains a “thought” that represents the key pieces of information, that is, the meaning, of the original input. We should then, as shown in Figure 7-13, be able to use this thought vector to either produce a label for the original sequence or produce an appropriate output sequence (translation, description, abstractive summary, etc.).
#
# ## Recurrent Neural Networks
# ![7-14](https://www.safaribooksonline.com/library/view/fundamentals-of-deep/9781491925607/assets/fodl_0714.png)
#
# Figure 7-14. A recurrent layer contains recurrent connections, that is to say, connections between neurons that are located in the same layer
#
# It turns out that, given a fixed lifetime (say t time steps) of an RNN instance, we can actually express the instance as a feed-forward network (albeit irregularly structured).
#
# We perform the transformation by taking the neurons of the single recurrent layer and replicating them it t times, once for each time step. We similarly replicate the neurons of the input and output layers.
#
# ![7-15](https://www.safaribooksonline.com/library/view/fundamentals-of-deep/9781491925607/assets/fodl_0715.png)
#
# Figure 7-15. We can run an RNN through time to express it as a feedforward network that we can train using backpropagation
#
# ## The Challenges with Vanishing Gradients
# Let’s start our investigation by considering the simplest possible RNN, shown in Figure 7-16, with a single input neuron, a single output neuron, and a fully connected recurrent layer with one neuron.
#
# ![7-16](https://www.safaribooksonline.com/library/view/fundamentals-of-deep/9781491925607/assets/fodl_0716.png)
#
# Figure 7-16. A single neuron, fully connected recurrent layer (both compressed and unrolled) for the sake of investigating gradient-based learning algorithms
#
# Given nonlinearity f, we can express the activation $h^{(t)}$ of the the hidden neuron of the recurrent layer at time step t as follows, where $i^{(t)}$ is the incoming logit from the input neuron at time step t:
#
# $h^{(t)}=f(w_{in}^{(t)}i^{(t)}+w_{rec}^{(t-1)}h^{(t-1)})$
#
# Let’s try to compute how the activation of the hidden neuron changes in response to changes to the input logit from k time steps in the past. In analyzing this component of the backpropagation gradient expressions, we can start to quantify how much “memory” is retained from past inputs. We start by taking the partial derivative and apply the chain rule:
#
# $\frac{\partial h^{(t)}}{\partial i^{(t-k)}}=f'(w_{in}^{(t)}i^{(t)}+w_{rec}^{(t-1)}h^{(t-1)})\frac{\partial}{\partial i^{(t-k)}}(w_{in}^{(t)}i^{(t)}+w_{rec}^{(t-1)}h^{(t-1)})$
#
# Because the values of the input and recurrent weights are independent of the input logit at time step t - k, we can further simplify this expression:
#
# $\frac{\partial h^{(t)}}{\partial i^{(t-k)}}=f'(w_{in}^{(t)}i^{(t)}+w_{rec}^{(t-1)}h^{(t-1)})w_{rec}^{(t-1)}\frac{\partial h^{(t-1)}}{\partial i^{(i-k)}}$
#
# We also know that for all common nonlinearities (the tanh, logistic, and ReLU nonlinearities), the maximum value of |f'| is at most 1. This leads to the following recursive inequality:
#
# $|\frac{\partial h^{(t)}}{\partial i^{(t-k)}}| \le |w_{rec}^{(t-1)}| \cdot |\frac{\partial h^{(t-1)}}{\partial i^{(t-k)}}|$
#
# We can continue to expand this inequality recursively until we reach the base case, at step t-k:
#
# $|\frac{\partial h^{(t)}}{\partial i^{(t-k)}}| \le |w_{rec}^{(t-1)}| \cdots |w_{rec}^{(t-k)}| \cdot |\frac{\partial h^{(t-k)}}{\partial i^{(t-k)}}|$
#
# We can evaluate this partial derivative similarly to how we proceeded previously:
#
# $h^{(t-k)}=f(w_{in}^{(t-k)}i^{(t-k)}+w_{rec}^{(t-k-1)}h^{(t-k-1)})$
#
# $\frac{\partial h^{(t-k)}}{\partial i^{(t-k)}}=f'(w_{in}^{(t-k)}i^{(t-k)}+w_{rec}^{(t-k-1)}h^{(t-k-1)})\frac{\partial}{\partial i^{(t-k)}}(w_{in}^{(t-k)}i^{(t-k)}+w_{rec}^{(t-k-1)}h^{(t-k-1)})$
#
# In this expression, the hidden activation at time t - k - 1 is independent of the value of the input at t - k. Thus we can rewrite this expression as:
#
# $\frac{\partial h^{(t-k)}}{\partial i^{(t-k)}}=f'(w_{in}^{(t-k)}i^{(t-k)}+w_{rec}^{(t-k-1)}h^{(t-k-1)})w_{in}^{(t-k)}$
#
# Finally, taking the absolute value on both sides and again applying the observation about the maximum value of |f'|, we can write:
#
# $|\frac{\partial h^{(t-k)}}{\partial i^{(t-k)}}| \le |w_{in}^{(t-k)}|$
#
# This results in the final inequality (which we can simplify because we constrain the connections at different time steps to have equal value):
#
# $|\frac{\partial h^{(t)}}{\partial i^{(t-k)}}| \le |w_{rec}^{(t-1)}| \cdots |w_{rec}^{(t-k)}| \cdot |w_{in}^{(t-k)}|=|w_{rec}|^k \cdot w_{in}$
#
# This relationship places a strong upper bound on how much a change in the input at time t - k can impact the hidden state at time t. **Because the weights of our model are initialized to small values at the beginning of training, the value of this derivative approaches zero as k increases.** This issue is commonly referred to as the problem of `vanishing gradients`.
#
# ## Long Short-Term Memory (LSTM) Units
# In  order  to combat the problem of vanishing gradients, Sepp Hochreiter and Jürgen Schmidhuber introduced the long short-term memory (`LSTM`) architecture. The basic principle behind the architecture was that the network would be designed for the purpose of reliably transmitting important information many time steps into the future. The design considerations resulted in the architecture shown in Figure 7-17.
#
# ![7-17](https://www.safaribooksonline.com/library/view/fundamentals-of-deep/9781491925607/assets/fodl_0717.png)
#
# Figure 7-17. The architecture of an LSTM unit, illustrated at a tensor (designated by arrows) and operation (designated by the purple blocks) level
#
# First, the unit must determine how much of the previous memory to keep. This is determined by the `keep gate`, shown in detail in Figure 7-18.
#
# ![7-18](https://www.safaribooksonline.com/library/view/fundamentals-of-deep/9781491925607/assets/fodl_0718.png)
#
# Figure 7-18. Architecture of the keep gate of an LSTM unit
#
# The memory state tensor from the previous time step is rich with information, but some of that information may be stale (and therefore might need to be erased). We figure out which elements in the memory state tensor are still relevant and which elements are irrelevant by trying to compute a bit tensor (a tensor of zeros and ones) that we multiply with the previous state. If a particular location in the bit tensor holds a 1, it means that location in the memory cell is still relevant and ought to be kept. If that particular location instead held a 0, it means that the location in the memory cell is no longer relevant and ought to be eased. We approximate this bit tensor by concatenating the input of this time step and the LSTM unit’s output from the previous time step and applying a sigmoid layer to the resulting tensor. A sigmoidal neuron, as you may recall, outputs a value that is either very close to 0 or very close to 1 most of the time (the only exception is when the input is close to zero). As a result, the output of the sigmoidal layer is a close approximation of a bit tensor, and we can use this to complete the keep gate.
#
# This part of the LSTM unit is known as the `write gate`, and it’s depicted in Figure 7-19.  This is broken down into two major parts. The first component is figuring out what information we’d like to write into the state. This is computed by the tanh layer to create an intermediate tensor. The second component is figuring out which components of this computed tensor we actually want to include into the new state and which we want to toss before writing. We do this by approximating a bit vector of 0’s and 1’s using the same strategy (a sigmoidal layer) as we used in the keep gate.  We multiply the bit vector with our intermediate tensor and then add the result to create the new state vector for the LSTM.
#
# ![7-19](https://www.safaribooksonline.com/library/view/fundamentals-of-deep/9781491925607/assets/fodl_0719.png)
#
# Figure 7-19. Architecture of the write gate of an LSTM unit
#
# Finally, at every time step, we’d like the LSTM unit to provide an output. The architecture of the output gate is shown in Figure 7-20. We use a nearly identical structure as the write gate: 1) the tanh layer creates an intermediate tensor from the state vector, 2) the sigmoid layer produces a bit tensor mask using the current input and previous output, and 3) the intermediate tensor is multiplied with the bit tensor to produce the final output.
#
# ![7-20](https://www.safaribooksonline.com/library/view/fundamentals-of-deep/9781491925607/assets/fodl_0720.png)
#
# Figure 7-20. Architecture of the output gate of an LSTM unit
#
# So why is this better than using a raw RNN unit? The unrolled architecture is shown in Figure 7-21. At the very top, we can observed the propagation of the state vector, whose interactions are primarily linear through time. The result is that the gradient that relates an input several time steps in the past to **the current output does not attenuate as dramatically as in the vanilla RNN architecture.** This means that **the LSTM can learn long-term relationships much more effectively than our original formulation of the RNN.**
#
# ![7-21](https://www.safaribooksonline.com/library/view/fundamentals-of-deep/9781491925607/assets/fodl_0721.png)
#
# Figure 7-21. Unrolling an LSTM unit through time
#
# Well, just as we can we can stack RNN layers to create more expressive models with more capacity, we can similarly stack LSTM units, where the input of the second unit is the output of the first unit, the input of the third unit is the output of the second, and so on. An illustration of how this works is shown in Figure 7-22, with a multicellular made of two LSTM units. This means that anywhere we use a vanilla RNN layer, we can easily substitute an LSTM unit.
#
# ![7-22](https://www.safaribooksonline.com/library/view/fundamentals-of-deep/9781491925607/assets/fodl_0722.png)
#
# Figure 7-22. Composing LSTM units as one might stack recurrent layers in a neural network
#
# [1]: https://github.com/tensorflow/models/tree/master/research/syntaxnet
# [2]: https://arxiv.org/abs/1603.06042
#
# ## Implementing a Sentiment Analysis Model
# In this section, we attempt to analyze the sentiment of movie reviews taken from the Large Movie Review Dataset. This dataset consists of 50,000 reviews from IMDB, each of which labeled as having positive or negative sentiment.
#
# We use the **IMDBDataset** Python class([read_imdb_data.py](read_imdb_data.py)) to serve both the training and validation sets we’ll use while training our sentiment analysis model.
#
# First, we’ll want to map each word in the input review to a word vector. To do this, we’ll utilize an embedding layer, which, is a simple lookup table that stores an embedding vector that corresponds to each word.
#
# [imdb_lstm.py](imdb_lstm.py):
#
#
# ```py
# def embedding_layer(input, weight_shape):
#     weight_init = tf.random_normal_initializer(stddev=(
#                     1.0/weight_shape[0])**0.5)
#     E = tf.get_variable("E", weight_shape,
#                         initializer=weight_init)
#     incoming = tf.cast(input, tf.int32)
#     embeddings = tf.nn.embedding_lookup(E, incoming)
#     return embeddings
# ```
#
# We then take the result of the embedding layer and build an LSTM with dropout:
#
# ```py
# def lstm(input, hidden_dim, keep_prob, phase_train):
#     lstm = rnn.BasicLSTMCell(hidden_dim)
#     dropout_lstm = rnn.DropoutWrapper(lstm, input_keep_prob=keep_prob, output_keep_prob=keep_prob)
#     lstm_outputs, state = tf.nn.dynamic_rnn(dropout_lstm, input, dtype=tf.float32)
#     return tf.reduce_max(lstm_outputs, reduction_indices=[1])
# ```
#
# Stringing all of these components together, we can build the inference graph:
#
# ```py
# def inference(input, phase_train):
#     embedding = embedding_layer(input, [30000, 512])
#     lstm_output = lstm(embedding, 512, 0.5, phase_train)
#     output = layer(lstm_output, [512, 2], [2], phase_train)
#     return output
# ```

# %%
import tensorflow as tf
from lstm import LSTMCell
import read_imdb_data as data
from imdb_lstm import loss, training, evaluate, inference

training_epochs = 1 # 1000
batch_size = 32
display_step = 1


with tf.Graph().as_default():
    with tf.device('/gpu:0'):
        x = tf.placeholder("float", [None, 500])
        y = tf.placeholder("float", [None, 2])
        phase_train = tf.placeholder(tf.bool)

        output = inference(x, phase_train)

        cost, train_loss_summary_op, val_loss_summary_op = loss(output, y)

        global_step = tf.Variable(0, name='global_step', trainable=False)

        train_op = training(cost, global_step)

        eval_op, eval_summary_op = evaluate(output, y)

        saver = tf.train.Saver(max_to_keep=100)

        sess = tf.Session(config=tf.ConfigProto(allow_soft_placement=True, log_device_placement=True))

        summary_writer = tf.summary.FileWriter("imdb_lstm_logs/", graph=sess.graph)

        init_op = tf.global_variables_initializer()

        sess.run(init_op)

        for epoch in range(training_epochs):
            avg_cost = 0.
            total_batch = int(data.train.num_examples/batch_size)
            print "Total of %d minbatches in epoch %d" % (total_batch, epoch)
            # Loop over all batches
            for i in range(total_batch):
                minibatch_x, minibatch_y = data.train.minibatch(batch_size)
                # Fit training using batch data
                _, new_cost, train_summary = sess.run([train_op, cost, train_loss_summary_op], feed_dict={x: minibatch_x, y: minibatch_y, phase_train: True})
                summary_writer.add_summary(train_summary, sess.run(global_step))
                # Compute average loss
                avg_cost += new_cost/total_batch
                print "Training cost for batch %d in epoch %d was:" % (i, epoch), new_cost
                if i % 100 == 0:
                    print "Epoch:", '%04d' % (epoch+1), "Minibatch:", '%04d' % (i+1), "cost =", "{:.9f}".format((avg_cost * total_batch)/(i+1))
                    val_x, val_y = data.val.minibatch(data.val.num_examples)
                    val_accuracy, val_summary, val_loss_summary = sess.run([eval_op, eval_summary_op, val_loss_summary_op], feed_dict={x: val_x, y: val_y, phase_train: False})
                    summary_writer.add_summary(val_summary, sess.run(global_step))
                    summary_writer.add_summary(val_loss_summary, sess.run(global_step))
                    print "Validation Accuracy:", val_accuracy

                    saver.save(sess, "imdb_lstm_logs/model-checkpoint-" + '%04d' % (epoch+1), global_step=global_step)
            # Display logs per epoch step
            # if epoch % display_step == 0:
            #     print "Epoch:", '%04d' % (epoch+1), "cost =", "{:.9f}".format(avg_cost)
            #     val_x, val_y = data.val.minibatch(data.val.num_examples)
            #     val_accuracy, val_summary, val_loss_summary = sess.run([eval_op, eval_summary_op, val_loss_summary_op], feed_dict={x: val_x, y: val_y, phase_train: False})
            #     summary_writer.add_summary(val_summary, sess.run(global_step))
            #     summary_writer.add_summary(val_loss_summary, sess.run(global_step))
            #     print "Validation Accuracy:", val_accuracy
            #
            #     saver.save(sess, "imdb_lstm_logs/model-checkpoint-" + '%04d' % (epoch+1), global_step=global_step)

        print "Optimization Finished!"
# Out:
# Total of 703 minbatches in epoch 0
# Training cost for batch 0 in epoch 0 was: 0.69461
# Epoch: 0001 Minibatch: 0001 cost = 0.694610476
# Validation Accuracy: 0.4952
# Training cost for batch 1 in epoch 0 was: 0.69163
# Training cost for batch 2 in epoch 0 was: 0.692238
# Training cost for batch 3 in epoch 0 was: 0.690888
# Training cost for batch 4 in epoch 0 was: 0.685791
# Training cost for batch 5 in epoch 0 was: 0.693556
# Training cost for batch 6 in epoch 0 was: 0.687123
# Training cost for batch 7 in epoch 0 was: 0.680736
# Training cost for batch 8 in epoch 0 was: 0.657541
# Training cost for batch 9 in epoch 0 was: 0.639738
# Training cost for batch 10 in epoch 0 was: 0.657558
# Training cost for batch 11 in epoch 0 was: 0.627809
# Training cost for batch 12 in epoch 0 was: 0.624833
# Training cost for batch 13 in epoch 0 was: 0.67078
# Training cost for batch 14 in epoch 0 was: 0.720676
# Training cost for batch 15 in epoch 0 was: 0.60072
# Training cost for batch 16 in epoch 0 was: 0.595772
# Training cost for batch 17 in epoch 0 was: 0.666266
# Training cost for batch 18 in epoch 0 was: 0.688608
# Training cost for batch 19 in epoch 0 was: 0.625562
# Training cost for batch 20 in epoch 0 was: 0.715435
# Training cost for batch 21 in epoch 0 was: 0.691504
# Training cost for batch 22 in epoch 0 was: 0.690176
# Training cost for batch 23 in epoch 0 was: 0.672883
# Training cost for batch 24 in epoch 0 was: 0.683877
# Training cost for batch 25 in epoch 0 was: 0.6884
# Training cost for batch 26 in epoch 0 was: 0.648079
# Training cost for batch 27 in epoch 0 was: 0.696074
# Training cost for batch 28 in epoch 0 was: 0.684036
# Training cost for batch 29 in epoch 0 was: 0.688762
# Training cost for batch 30 in epoch 0 was: 0.698969
# Training cost for batch 31 in epoch 0 was: 0.656407
# Training cost for batch 32 in epoch 0 was: 0.705557
# Training cost for batch 33 in epoch 0 was: 0.67694
# Training cost for batch 34 in epoch 0 was: 0.673406
# Training cost for batch 35 in epoch 0 was: 0.721943
# Training cost for batch 36 in epoch 0 was: 0.67475
# Training cost for batch 37 in epoch 0 was: 0.603673
# Training cost for batch 38 in epoch 0 was: 0.698421
# Training cost for batch 39 in epoch 0 was: 0.648832
# Training cost for batch 40 in epoch 0 was: 0.692536
# Training cost for batch 41 in epoch 0 was: 0.69172
# Training cost for batch 42 in epoch 0 was: 0.692659
# Training cost for batch 43 in epoch 0 was: 0.693091
# Training cost for batch 44 in epoch 0 was: 0.693471
# Training cost for batch 45 in epoch 0 was: 0.690796
# Training cost for batch 46 in epoch 0 was: 0.6916
# Training cost for batch 47 in epoch 0 was: 0.692515
# Training cost for batch 48 in epoch 0 was: 0.690709
# Training cost for batch 49 in epoch 0 was: 0.692263
# Training cost for batch 50 in epoch 0 was: 0.693014
# Training cost for batch 51 in epoch 0 was: 0.690811
# Training cost for batch 52 in epoch 0 was: 0.691327
# Training cost for batch 53 in epoch 0 was: 0.692045
# Training cost for batch 54 in epoch 0 was: 0.691887
# Training cost for batch 55 in epoch 0 was: 0.692069
# Training cost for batch 56 in epoch 0 was: 0.691747
# Training cost for batch 57 in epoch 0 was: 0.691613
# Training cost for batch 58 in epoch 0 was: 0.69178
# Training cost for batch 59 in epoch 0 was: 0.687734
# Training cost for batch 60 in epoch 0 was: 0.761224
# Training cost for batch 61 in epoch 0 was: 0.705037
# Training cost for batch 62 in epoch 0 was: 0.684866
# Training cost for batch 63 in epoch 0 was: 0.71286
# Training cost for batch 64 in epoch 0 was: 0.724926
# Training cost for batch 65 in epoch 0 was: 0.676711
# Training cost for batch 66 in epoch 0 was: 0.678834
# Training cost for batch 67 in epoch 0 was: 0.648563
# Training cost for batch 68 in epoch 0 was: 0.737265
# Training cost for batch 69 in epoch 0 was: 0.645826
# Training cost for batch 70 in epoch 0 was: 0.705773
# Training cost for batch 71 in epoch 0 was: 0.7204
# Training cost for batch 72 in epoch 0 was: 0.733419
# Training cost for batch 73 in epoch 0 was: 0.677695
# Training cost for batch 74 in epoch 0 was: 0.652862
# Training cost for batch 75 in epoch 0 was: 0.730179
# Training cost for batch 76 in epoch 0 was: 0.672003
# Training cost for batch 77 in epoch 0 was: 0.665094
# Training cost for batch 78 in epoch 0 was: 0.677593
# Training cost for batch 79 in epoch 0 was: 0.615484
# Training cost for batch 80 in epoch 0 was: 0.696462
# Training cost for batch 81 in epoch 0 was: 0.777182
# Training cost for batch 82 in epoch 0 was: 0.657989
# Training cost for batch 83 in epoch 0 was: 0.652513
# Training cost for batch 84 in epoch 0 was: 0.686988
# Training cost for batch 85 in epoch 0 was: 0.733151
# Training cost for batch 86 in epoch 0 was: 0.731916
# Training cost for batch 87 in epoch 0 was: 0.755284
# Training cost for batch 88 in epoch 0 was: 0.703206
# Training cost for batch 89 in epoch 0 was: 0.690499
# Training cost for batch 90 in epoch 0 was: 0.660862
# Training cost for batch 91 in epoch 0 was: 0.748546
# Training cost for batch 92 in epoch 0 was: 0.74044
# Training cost for batch 93 in epoch 0 was: 0.761998
# Training cost for batch 94 in epoch 0 was: 0.744068
# Training cost for batch 95 in epoch 0 was: 0.693137
# Training cost for batch 96 in epoch 0 was: 0.704581
# Training cost for batch 97 in epoch 0 was: 0.697334
# Training cost for batch 98 in epoch 0 was: 0.710363
# Training cost for batch 99 in epoch 0 was: 0.652928
# Training cost for batch 100 in epoch 0 was: 0.693926
# Epoch: 0001 Minibatch: 0101 cost = 0.687781496

# %% [markdown]
# ## Solving seq2seq Tasks with Recurrent Neural Networks
# The first network is known as the encoder network. The **encoder** network is a recurrent network (usually one that uses LSTM units) that consumes the entire input sequence. The goal of the encoder network is to generate a condensed understanding of the input and summarize it into a singular thought represented by the final state of the encoder network. Then we use a **decoder** network, whose starting state is initialized with the final state of the encoder network, to produce the target output sequence token by token.
#
# ![](https://www.safaribooksonline.com/library/view/fundamentals-of-deep/9781491925607/assets/fodl_0724.png)
#
# Figure 7-24. Illustration of how we use an encoder/decoder recurrent network schema to tackle seq2seq problems
#
# In this this setup, we are attempting to translate an American sentence into French. We tokenize the input sentence and use an embedding (similarly to our approach in the sentiment analysis model we built in the previous section), one word at a time as an input to the encoder network. At the end of the sentence, we use a special “end of sentence” (EOS) token to indicate the end of the input sequence to the encoder network. Then we take the hidden state of the encoder network and use that as the initialization of the decoder network. The first input to the decoder network is the EOS token, and the output is interpreted as the first word of the predicted French translation. From that point onward, we use the output of the decoder network as the input to itself at the next time step. We continue until the decoder network emits an EOS token as its output, at which point we know that the network has completed producing the translation of the original English sentence.
#
# For example, Kiros et al. in 2015 invented the notion of a [skip-thought vector](https://papers.nips.cc/paper/5950-skip-thought-vectors). The skip-thought vector was generated by dividing up a passage into a set of triplets consisting of consecutive sentences. The authors utilized a single encoder network and two decoder networks:
#
# ![](https://www.safaribooksonline.com/library/view/fundamentals-of-deep/9781491925607/assets/fodl_0725.png)
#
# Figure 7-25. The skip-thought seq2seq architecture to generate embedding representations of entire sentences
#
# ## Augmenting Recurrent Networks with Attention
# ![](https://www.safaribooksonline.com/library/view/fundamentals-of-deep/9781491925607/assets/fodl_0726.png)
#
# Figure 7-26. An attempt at engineering attentional abilities in a seq2seq architecture. This attempt falls short because it fails to dynamically select the most relevant parts of the input to focus on.
#
# The key realization here is that it’s not enough to merely give the decoder access to all the outputs. Instead, we must engineer a mechanism by which the decoder network can dynamically pay **attention** to a specific subset of the encoder’s outputs.
#
# ![](https://www.safaribooksonline.com/library/view/fundamentals-of-deep/9781491925607/assets/fodl_0727.png)
#
# Figure 7-27. A modification to our original proposal that enables a dynamic attentional mechanism based on the hidden state of the decoder network in the previous time step
