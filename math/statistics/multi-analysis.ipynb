# %% [markdown]
# # 多元分析
# 三种多元分析方法：
#
# 因变量 | 自变量 | 方法
# ------| ---- | ---
# 分类型 | 分类型 | 偏ɸ法
# 数值型 | 数值型 | 多元回归
# 数值型 | 虚拟型 | 多元回归
# 数值型 | 两个分类型 | 双因子方差分析
#
# ## 偏ɸ：三个分类型变量
# 例子中存在三个分类变量：收入（高、低），性别，投票（共和党、民主党）
#
# ### 控制变量
# 表13.1显示了一则有关两个分类型变量性别与投票之间的关系的例子。两个变量间的关系强度用ɸ=0.21衡量。
#
# ![](http://ou8qjsj0m.bkt.clouddn.com//17-10-26/33866265.jpg)
#
# 控制第三个变量就是在研究两个变量之间的关系时，将数据按照被控制的变量先分成若干子部分，然后在被控制的各个子部分中研究那两个变量之间的关系。所谓按照第三个变量划分子部分意味着让第三变量保持常数。基于表13.1加入收入这个分类型变量：
#
# ![](http://ou8qjsj0m.bkt.clouddn.com//17-10-26/50391691.jpg)
#
# 在每个子表中(穷人和富人两张表)，ɸ=0.00，这意味着当考虑收入因素时，性别与投票之间的关系消失了。所以得出结论：原有的性别与投票之间的关系是虚假的。
#
# ### 偏ɸ系数(partial phis coefficient)
# 偏ɸ系数(partial phis coefficient)表明了当一个或多个其它变量被控制时，两个变量之间的关系强度。偏ɸ可以认为是每个部分内两个变量之间ɸ的平均值，而这些部分是根据控制变量来划分的。当我们控制收入时，偏ɸ=0.00也可被称为性别与投票的各组中的平均ɸ(average within group ɸ)。
#
# 表13.3显示收入与投票之间的关系：
#
# ![](http://ou8qjsj0m.bkt.clouddn.com//17-10-26/63808758.jpg)
#
# 表13.4显示控制性别因素时收入和投票之间的关系：
#
# ![](http://ou8qjsj0m.bkt.clouddn.com//17-10-26/8961542.jpg)
#
# 就多元分析而言每个箭头表示了分析中其它变量在场时相应变量的ɸ。当收入是唯一自变量时，它与投票之间关系的强度是0.45，而当性别因素出现时，这种强度减少到0.40：
#
# ![](http://ou8qjsj0m.bkt.clouddn.com//17-10-26/9852773.jpg)
#
# 在表13.2两个列联表中，第一个表中贫穷的人倾向于支持民主党而富裕的人倾向于支持共和党。在第二个表中女性一般比较贫穷而男性一般比较富裕。是性别影响收入而收入影响投票。我们所观察到的性别与投票之间的关系是性别对收入的效应和收入对投票的效应的附属品：
#
# ![](http://ou8qjsj0m.bkt.clouddn.com//17-10-26/85383098.jpg)
#
# ## 数值型变量的多元回归
# 多元回归分析(multiple regression analysis)是一种用于研究多个数值型自变量与一个数值型因变量之间关系的统计方法。
#
# 两个数值型变量的回归分析和相关分析中，我们研究了小吃中热量与脂肪含量的关系。在同样的食品中还会发现胆固醇的含量和钠的含量。
#
# ### 偏回归系数(partial regression coefficients)与共线性(collinearity)
# 热量=21.3+12.6脂肪-0.11胆固醇+0.18钠
#
# 方程中三个系数是偏回归系数(partial regression coefficients)。偏回归系数是当我们控制其它所有自变量并使它们保持常值时，某一变量的系数。它是当我们按分析中所有其它自变量的值分组后各个组内回归系数的平均值。
#
# 图13.3表明由于脂肪和钠的出现，胆固醇几乎与热量无关：
#
# ![](http://ou8qjsj0m.bkt.clouddn.com//17-10-26/83770775.jpg)
#
# 上述系数改变的原因是脂肪、胆固醇和钠三个自变量之间互相有关系：
# * 脂肪(fat)与胆固醇(cholesterol)的r=0.69
# * 脂肪(fat)与钠(sodium)的r=0.59
# * 胆固醇(cholesterol)与钠(sodium)的r=0.41
#
# 每当我们引入一个与分析中变量有相互关系的变量时，回归系数就发生了改变。没有哪一个变量会保持唯一的系数值；系数会随着我们所用的其它变量而改变。这种现象称为自变量之间的共线性(collinearity)。
#
# ### 偏相关系数(partial correlation coefficient)(偏r(或ɸ))
# 一个偏相关系数(partial correlation coefficient)表明了当我们控制其它变量时两个变量之间关系的强度。
# * 对于三个x1,x2,x3表示的变量，控制x3时，x1,x2的偏相关系数(用r12.3)： $r_{12.3}=\frac{r_{12}-r_{13}r_{23}}{\sqrt{(1-r_{13}^2)(1-r_{23}^2)}}$
# * 对ɸ用同样的公式，只是用ɸ代替r。
#
# ### 多重相关系数(multiple correlation coefficient)
# 多重相关系数(multiple correlation coefficient)R度量因变量的观测值与自变量由回归方程算得的预测值之间的关系强度。R的值域从0到1。
#
# 多重相关系数的平方R2等于0.89，它意味着三个自变量共同解释了热量值差异的89%，残差变量解释了剩下的11%。
#
# ### R的假设检验(F检验)
# R的假设检验：零假设“总体中的多重相关系数R为0”，样本得出的R为0.94，由F-变量来计算R的p-值。得出F=31.3，自由度为3和12。F为31.3或更大的概率为0.000006；故我们拒绝零假设。
#
# 基于k个自变量和n个观测值，检验总体R为0的零假设： $F=\frac{R^2}{1-R^2}\frac{n-k-1}{k},d.f.=k,n-k-1$
#
# ### 每个自变量的假设检验(t检验)
# R的值是高度显著的，但它并没有向我们展示是否所有三个自变量均具有统计上的显著效应。
#
# 零假设“小吃中脂肪的偏回归系数为12.6，总体数据中相应的系数可以为0吗？”把12.6变为t-变量的一个值，t=4.98，自由度为12，t为12.6或更大值的概率为0.00016。故拒绝零假设。我们也可以去估计这个系数，并得到偏总体回归系数的95%置信区间为7.1到18.1。
#
# 类似地，胆固醇的偏回归系数为-0.11，p-值为0.44，p-值如此大，故我们不拒绝没有效应的零假设，总体中相应的系数很可能为0。我们得出热量和胆固醇可能无关的结论。
#
# 对钠变量，偏回归系数为0.18的t=2.46.这个t的p-值为0.015，它已经足够小，从而使我们拒绝零假设并得出小吃中热量与钠变量有关的结论。
#
# ## 用一个哑元作多元回归
# 将一个分类变量转变为一个虚拟变量，这样可以进行回归分析。下面的例子性别是分类变量，变成虚拟变量，当性别为女时为0，性别为男时为1。研究：学院在付给教授薪水上是否存在性别歧视。薪水与性别的散点图，得出薪水=71.1+5.2性别：
#
# ![](http://ou8qjsj0m.bkt.clouddn.com//17-10-26/21196192.jpg)
#
# 加入年龄，做多元分析后，得出薪水=40+0.0性别+0.5年龄，下面的几组散点图：
#
# ![](http://ou8qjsj0m.bkt.clouddn.com//17-10-26/63013184.jpg)
#
# 此时发现性别对于薪水的影响消失了。一个合理的解释是，影响薪水的因素是年龄，而女性教授的年龄普遍低于男性教授。
#
# ## 双因子方差分析
# 双因子方差分析(two-way analysis of variance)是有关两个分类型自变量对一个数值型因变量效应的分析。路线(Main Street/High Street)和时段(高峰/非高峰)是分类型变量，都有两个值。驾驶时间是一个数值型变量，以分钟计算：
#
# ![](http://ou8qjsj0m.bkt.clouddn.com//17-10-26/48715284.jpg)
#
# 仅对于时段的单因子分析，统计显著的(拒绝零假设)：
#
# ![](http://ou8qjsj0m.bkt.clouddn.com//17-10-26/50113774.jpg)
#
# 仅对于路线的单因子分析，统计较显著(拒绝零假设)：
#
# ![](http://ou8qjsj0m.bkt.clouddn.com//17-10-26/52664596.jpg)
#
# 时段和路线的双因子分析：
# * 总平均：驾驶时间均值=20分钟
# * 行效应：高峰时段效应=23分钟-20分钟=3分钟；非高峰时段效应=17分钟-20分钟=-3分钟
# * 列效应：Main Street效应=22分钟-20分钟=2分钟；High Street效应=18分钟-20分钟=-2分钟
# * 由总均值、行效应和列效应计算不同路线和不同时段的平均驾驶时间：
#
# ![](http://ou8qjsj0m.bkt.clouddn.com//17-10-26/89470399.jpg)
#
# ![](http://ou8qjsj0m.bkt.clouddn.com//17-10-26/41844301.jpg)
#
# * 残差变量：在该例中，第一次驾驶花了26分钟，而不是均值25分钟，因此残差变量加了一分钟到这次驾驶。残差变量在其它次高峰时段沿Main Street上的驾驶的效应为-0.8，1.5，-0.9和-0.8分钟。
#
# ![](http://ou8qjsj0m.bkt.clouddn.com//17-10-26/79181315.jpg)
#
# ### 双因子方差分析公式
# 表13.13显示了当因变量的数值记号代替时怎样列出双因子方差分析的数据：
#
# ![](http://ou8qjsj0m.bkt.clouddn.com//17-10-26/97697350.jpg)
#
# * 不同的平方和计算：
#     * 行变量平方和= $\sum{n_{i.}(\bar{y_{i.}}-\bar{y})^2}$
#     * 列变量平方和= $\sum{n_{.j}(\bar{y_{.j}}-\bar{y})^2}$
#     * 交互变量平方和= $\sum\sum_{ij}\bar{(y_{ij}-\bar{y_{i.}}-\bar{y_{.j}}+\bar{y})^2}$
#     * 残差变量平方和= $\sum\sum\sum(y_{ijk}-\bar{y_{ij}})^2$
#     * 总平方和= $\sum\sum\sum(y_{ijk}-\bar{y})^2$
# * 对于r行、c列和每个单元内有m个观测值的情形由以下表达式算出自由度:
#     * 行变量自由度=r-1
#     * 列变量自由度=c-1
#     * 交互变量自由度=(r-1)(c-1)
#     * 残差变量自由度=rcm-rc
#     * 总自由度=rcm-1
#
# ### 问题：对每个自变量的分析中可以发现选择哪个时段哪个路线驾驶是有差异的。
# 在表13.6中，R2=0.57,R=0.75表示时段与驾驶时间的关系。类似，从表13.7，R2=0.25,R=0.50表示路线与驾驶时间的关系。
#
# 我们已经得出时间变量的平方和(180.00)与路线变量的平方和(80.00)。这两个变量的联合效应变成180.00+80.00=260.00。这两个自变量解释了驾驶时间差异的260.00/313.98=82%，而残差变量解释了差异中余下的18%。由于R2=0.82，所有自变量效应的多重相关系数R=0.91。于是，这两个变量合起来与驾驶时间有较强的关系。
#
# 总计平方和与两个自变量的联合效应之差为55.98，这是残差变量在双因子分析中的效应。如果我们计算了每个残差并对它们进行平方，这个平方和也等于55.98。双因子分析的残差平方和比任何单因子分析的残差平方和都小，因为残差变量现在不包括两个自变量中的任何一个。
#
# ### F检验
# 对两个变量，R2=0.82，由此得出F-变量的值为39.48，自由度为2和17。这个F的p-值等于0.0000004，故拒绝零假设。对每个变量分别做的假设显示在表13.10中。跟以前的两个方差分析相比残差平方和少了一个自由度，但净效应仍然是这里的残差均方要比表13.6和13.7中的两个残差均方小。因此，双因子分析中F-值比两个单因子分析中要大。大的F-值产生了更小的p-值。
#
# ![](http://ou8qjsj0m.bkt.clouddn.com//17-10-26/33614753.jpg)
#
# ### 考虑交互效应
# 一年后不同路线和时段的平均驾驶时间：
#
# ![](http://ou8qjsj0m.bkt.clouddn.com//17-10-26/9709887.jpg)
#
# ![](http://ou8qjsj0m.bkt.clouddn.com//17-10-26/8449179.jpg)
#
# 图13.9相比于图13.8，两条线不再平行。现在在高峰时段从Main Street驾驶的联合效应比这两个因素各自效应的和要大。这种附加效应称为交互效应(interaction effect)。它发生时，两个变量的联合作用对因变量产生了它们各自效应之和以外的附加效应。
#
# 交互效应的平方和等于20.00，交互变量解释了20.00/335.98=6%的驾驶时间差异。这样交互变量与驾驶时间的关系不是很强，R=0.24，表13.12显示所有三个变量的p-值都很小，这意味着它们都与驾驶时间有统计意义上显著的关系：
#
# ![](http://ou8qjsj0m.bkt.clouddn.com//17-10-26/79949836.jpg)
#
# 均方由平方和除以相应的自由度算得。F-比率由每个均方除以残差变量均方算得。所有这些数都列在如表13.12的方差分析表中。
